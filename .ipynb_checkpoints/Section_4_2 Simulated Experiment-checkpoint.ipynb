# %% [markdown]
# # Simulated Experiments (Section 4.2)
#
# First generate the dataset
#
# Then define the new model class
#
# Then generate the plots in the paper

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib import colors, ticker, cm

from pprint import pprint
from progressbar import progressbar

# %matplotlib inline

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 75

plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = 10, 6
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 10

plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = "serif"
plt.rcParams['font.serif'] = "cm"
plt.rcParams['text.latex.preamble'] = r"\usepackage{subdepth}, \usepackage{type1cm}"

# %%
num_queries = 100
cs_size = 10
def get_relevance_labels(xs):
#     return np.clip(np.floor(xs[:, 1]+xs[:,0]), 0.0, 4.0)
    return np.clip(xs[:,2] + xs[:,1], 0.0, 4.0)
    
feats = []
rels = []
for i in range(num_queries):
    groups = np.random.choice(2, size=cs_size, p=[0.8, 0.2])
    #x1s = [np.random.normal(1.0, 0.5) if groups[i]==0 else np.random.normal(2.0, 0.5) for i in range(cs_size)]
    x1s = 3*np.random.random(cs_size)
    x2s = 3*np.random.random(cs_size)
    labels = get_relevance_labels(np.vstack((groups, x1s, x2s)).transpose())
    x2observed = x2s
    x2observed[groups==1] = 0 #3*np.random.random(np.sum(groups==1))
    xs = np.vstack((groups, x1s, x2observed)).transpose()
    feats.append(xs)
    rels.append(labels)

# %%
pwd
# Out:
# '/home/ashudeep/projects/fairness/fair_pgrank_ltr'

# %%
from train_yahoo_dataset import on_policy_training
from YahooDataReader import YahooDataReader
import torch
from models import NNModel, LinearModel
from evaluation import evaluate_model

# %%
dr = YahooDataReader(None)
dr.data = (feats, rels)
# vdr = YahooDataReader(None)
# vdr.data = (val_feats, val_rels)
vdr = dr

# %%
plt.grid()

feats_ = np.reshape(np.asarray(feats), (num_queries*cs_size, 3))
rels_ = np.asarray(rels).flatten()
plt.scatter(feats_[:,1], feats_[:,2], c=rels_)
plt.colorbar()
# Out:
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.grid()

feats_ = np.reshape(np.asarray(feats), (num_queries*cs_size, 3))
rels_ = np.asarray(rels).flatten()
plt.scatter(feats_[:,1], feats_[:,2], c=feats_[:,0])
plt.colorbar()

# %%
class Namespace:
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)
args = Namespace(conditional_model=True, gpu_id=None, progressbar=True, evaluate_interval=250, input_dim=3, 
                 eval_rank_limit=1000,
                fairness_version="asym_disparity", entropy_regularizer=0.0, save_checkpoints=False, num_cores=1,
                pooling='concat_avg', dropout=0.0, hidden_layer=8, group_feat_id=0, summary_writing=False, 
                 group_fairness_version="asym_disparity",early_stopping=False, lr_scheduler=False, 
                 validation_deterministic=False, evalk=1000, reward_type="ndcg", baseline_type="value", 
                 use_baseline=True, entreg_decay=0.0, skip_zero_relevance=True, eval_temperature=1.0, optimizer="Adam",
                clamp=False)
torch.set_num_threads(args.num_cores)
args.group_feat_id = 0
args.progressbar = False 

args.lr = 0.1
args.lr_scheduler = True
args.weight_decay = 0.0
args.lr_decay = 0.5

# %%
from models import CustomLinearModel

# %%
def eval_params(w1, w2, vdr, det=False):
    model = CustomLinearModel(D=3, fix_weight_dim=0)
    model.w.weight.data = torch.tensor([[w1, w2]])
    return evaluate_model(model, vdr, deterministic=det, group_fairness_evaluation=True, args=args, fairness_evaluation=True)

# %%
w1s = np.linspace(0, 5, num=20)
w2s = np.linspace(0, 5, num=20)
Z = np.zeros((20,20))
Z2 = np.zeros((20,20))
for i, w1 in enumerate(w1s):
    print("At {}/{} w1s".format(i, len(w1s)))
    for j, w2 in enumerate(w2s):
        res = eval_params(w1, w2)
        Z[i,j] = res["ndcg"]
        Z2[i,j] = res["avg_group_asym_disparity"]
Z = Z.transpose()
Z2 = Z2.transpose()
plt.matshow(Z)
plt.colorbar()
plt.show()
plt.matshow(Z2)
plt.colorbar()
# Out:
# At 0/20 w1s
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# At 1/20 w1s
# At 2/20 w1s
# At 3/20 w1s
# At 4/20 w1s
# At 5/20 w1s
# At 6/20 w1s
# At 7/20 w1s
# At 8/20 w1s
# At 9/20 w1s
# At 10/20 w1s
# At 11/20 w1s
# At 12/20 w1s
# At 13/20 w1s
# At 14/20 w1s
# At 15/20 w1s
# At 16/20 w1s
# At 17/20 w1s
# At 18/20 w1s
# At 19/20 w1s

# %%
Z2.max(), Z2.min()
# Out:
# (0.016788931730526868, 0.0013729649673009155)

# %%
model_params_list = []
disparities = []
lambdas_list = [0, 1, 2, 3,5,7,8, 10, 15, 20, 25]
for lgroup in lambdas_list:
    torch.set_num_threads(args.num_cores)
    args.epochs = 5
    args.progressbar = False
    args.weight_decay = 0.0
    args.sample_size = 10
    args.pooling = False
    args.skip_zero_relevance = True
    args.validation_deterministic = False
    args.lambda_reward = 1.0
    args.lambda_ind_fairness = 0.0
    args.lambda_group_fairness = lgroup


    model = CustomLinearModel(D=args.input_dim, use_bias=False, fix_weight_dim=0)
    
    model = on_policy_training(dr, vdr, model, args=args)
    results = evaluate_model(model, vdr, fairness_evaluation=False, group_fairness_evaluation=True, 
                             deterministic=False, args=args, num_sample_per_query=20)
    print(results)
    model_params_list.append(model.w.weight.data.tolist()[0])
    print("Learnt model for lambda={} has model weights as {}".format(lgroup, model_params_list[-1]))
    disparities.append(results["avg_group_asym_disparity"])
# Out:
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:0
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.7664358545892425, DCG 33.8567930906805, Average Rank 4.5, ERR 0.6103630591853773
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.9729314563329915, DCG 42.63092871108652, Average Rank 4.5, ERR 0.9416261994820876
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.9756008501448015, DCG 42.754849693324296, Average Rank 4.5, ERR 0.9440494786155863
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.9756173438976933, DCG 42.752281916106675, Average Rank 4.5, ERR 0.9439592134412937
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.9765988054146358, DCG 42.79549952807886, Average Rank 4.5, ERR 0.9464152953965989
# Epoch 4, Average Validation: NDCG: 0.976507934585163, DCG 42.78989436128708, Average Rank 4.5, ERR 0.944674535174204
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# {'ndcg': 0.9759446219971198, 'dcg': 42.77131778728378, 'avg_rank': 4.5, 'err': 0.9451873288916395, 'avg_group_disparity': 0.00613862179478359, 'avg_group_asym_disparity': 0.01363780448431462}
# Learnt model for lambda=0 has model weights as [3.8032543659210205, 3.521402359008789]
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:1
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.80888076606738, DCG 35.68382800091905, Average Rank 4.5, ERR 0.6803774212632497
# Average Validation Group Exposure disparity: 0.01771551980718076, Group Asymmetric disparity: 0.010552886943566925
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.9722259393540269, DCG 42.61112033544859, Average Rank 4.5, ERR 0.9367849278625758
# Average Validation Group Exposure disparity: 0.0056471345043918875, Group Asymmetric disparity: 0.012790202024960638
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.9749707285128892, DCG 42.7272713715485, Average Rank 4.5, ERR 0.942926929533297
# Average Validation Group Exposure disparity: 0.0060238997367037675, Group Asymmetric disparity: 0.013636610382128876
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.9771836002802756, DCG 42.815440268595715, Average Rank 4.5, ERR 0.946521179412631
# Average Validation Group Exposure disparity: 0.0059280392372823435, Group Asymmetric disparity: 0.013436917449431823
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.9762312195370673, DCG 42.782146361468506, Average Rank 4.5, ERR 0.9449691012477476
# Average Validation Group Exposure disparity: 0.0059492183410250355, Group Asymmetric disparity: 0.013331734515661754
# Epoch 4, Average Validation: NDCG: 0.9764758291229306, DCG 42.79159361621842, Average Rank 4.5, ERR 0.9439468433919782
# Average Validation Group Exposure disparity: 0.0060370313274322705, Group Asymmetric disparity: 0.013561967871874154
# {'ndcg': 0.977229095138509, 'dcg': 42.82096762146164, 'avg_rank': 4.5, 'err': 0.9463662115515874, 'avg_group_disparity': 0.005933195262494492, 'avg_group_asym_disparity': 0.013330653546169833}
# Learnt model for lambda=1 has model weights as [3.8906595706939697, 3.3356189727783203]
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:2
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.7621205295484309, DCG 33.662560312486164, Average Rank 4.5, ERR 0.6045536432825585
# Average Validation Group Exposure disparity: 0.027323232174702304, Group Asymmetric disparity: 0.003223558703524288
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.9671339687441245, DCG 42.401811969776084, Average Rank 4.5, ERR 0.9274737443432619
# Average Validation Group Exposure disparity: 0.0053486150627556515, Group Asymmetric disparity: 0.011217059378425296
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.9692561962857222, DCG 42.49453692039853, Average Rank 4.5, ERR 0.9303646719116864
# Average Validation Group Exposure disparity: 0.00523726396253335, Group Asymmetric disparity: 0.011114436071775901
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.9719324504664811, DCG 42.59893120514857, Average Rank 4.5, ERR 0.9360419075014816
# Average Validation Group Exposure disparity: 0.005387371398090082, Group Asymmetric disparity: 0.011308486960242965
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.9741652318913303, DCG 42.696118271925485, Average Rank 4.5, ERR 0.9398698425956438
# Average Validation Group Exposure disparity: 0.005443654959255305, Group Asymmetric disparity: 0.012077523069213052
# Epoch 4, Average Validation: NDCG: 0.9718669065675637, DCG 42.60527876398805, Average Rank 4.5, ERR 0.9356287972167684
# Average Validation Group Exposure disparity: 0.0055173587042999265, Group Asymmetric disparity: 0.01202889592883998
# {'ndcg': 0.9736165810665101, 'dcg': 42.67686062042841, 'avg_rank': 4.5, 'err': 0.9382347384498986, 'avg_group_disparity': 0.005533665790263788, 'avg_group_asym_disparity': 0.011930233611645332}
# Learnt model for lambda=2 has model weights as [3.7721621990203857, 2.484619140625]
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:3
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.8278177255404866, DCG 36.510692286041156, Average Rank 4.5, ERR 0.7089894721878085
# Average Validation Group Exposure disparity: 0.009845008999372497, Group Asymmetric disparity: 0.001629891867157169
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.9670255194130348, DCG 42.39915765726857, Average Rank 4.5, ERR 0.9288143863071006
# Average Validation Group Exposure disparity: 0.0053913923890385055, Group Asymmetric disparity: 0.011786890273640058
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.9681296070108146, DCG 42.448960560284505, Average Rank 4.5, ERR 0.9310985331479712
# Average Validation Group Exposure disparity: 0.005177822976899567, Group Asymmetric disparity: 0.01092998668807352
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.9691009574304539, DCG 42.48214175737061, Average Rank 4.5, ERR 0.9288974136623037
# Average Validation Group Exposure disparity: 0.005150064270488529, Group Asymmetric disparity: 0.011128249966023733
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.9720092398729875, DCG 42.60461214688266, Average Rank 4.5, ERR 0.9353555591726299
# Average Validation Group Exposure disparity: 0.005296763570249259, Group Asymmetric disparity: 0.011221496941390357
# Epoch 4, Average Validation: NDCG: 0.9712691890746595, DCG 42.581301283791234, Average Rank 4.5, ERR 0.9356672644163037
# Average Validation Group Exposure disparity: 0.005282213086852151, Group Asymmetric disparity: 0.011133540990506414
# {'ndcg': 0.9711588910881446, 'dcg': 42.57181365619726, 'avg_rank': 4.5, 'err': 0.9340724805230175, 'avg_group_disparity': 0.0052046096330750245, 'avg_group_asym_disparity': 0.011166787747665285}
# Learnt model for lambda=3 has model weights as [4.072969436645508, 2.231496810913086]
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:5
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.8307196608071645, DCG 36.61093113257257, Average Rank 4.5, ERR 0.7203123706947575
# Average Validation Group Exposure disparity: 0.008739302562156449, Group Asymmetric disparity: 0.0012509741151485625
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.9606331980112519, DCG 42.14271573067493, Average Rank 4.5, ERR 0.918283303204608
# Average Validation Group Exposure disparity: 0.004929378740591862, Group Asymmetric disparity: 0.009773850285069123
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.9663135201453511, DCG 42.36645542410656, Average Rank 4.5, ERR 0.9261084108733029
# Average Validation Group Exposure disparity: 0.005188023257774392, Group Asymmetric disparity: 0.010954330142309222
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.9672671049664885, DCG 42.413125172698884, Average Rank 4.5, ERR 0.927440486929013
# Average Validation Group Exposure disparity: 0.0051117670428335185, Group Asymmetric disparity: 0.010231965069409994
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.9669187334209848, DCG 42.39241540816058, Average Rank 4.5, ERR 0.9265801139180241
# Average Validation Group Exposure disparity: 0.005038177528400488, Group Asymmetric disparity: 0.01038152207621053
# Epoch 4, Average Validation: NDCG: 0.9675766669052704, DCG 42.42097905391473, Average Rank 4.5, ERR 0.9287660827884793
# Average Validation Group Exposure disparity: 0.005122830175637693, Group Asymmetric disparity: 0.010696183754682207
# {'ndcg': 0.9665599659418196, 'dcg': 42.3801090860283, 'avg_rank': 4.5, 'err': 0.925798927250794, 'avg_group_disparity': 0.005109535084664864, 'avg_group_asym_disparity': 0.010688879831515483}
# Learnt model for lambda=5 has model weights as [3.505352735519409, 1.7788547277450562]
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:7
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.7974006989526693, DCG 35.18103807343786, Average Rank 4.5, ERR 0.6583203789214334
# Average Validation Group Exposure disparity: 0.014957074526177491, Group Asymmetric disparity: 0.0025743249629920084
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.9553505136101458, DCG 41.89554800503588, Average Rank 4.5, ERR 0.9100841408887658
# Average Validation Group Exposure disparity: 0.005128410267620177, Group Asymmetric disparity: 0.009878773403748885
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.959067490913166, DCG 42.05041587228016, Average Rank 4.5, ERR 0.9155962607800515
# Average Validation Group Exposure disparity: 0.005267546621990823, Group Asymmetric disparity: 0.010181299022653993
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.9551483824480137, DCG 41.90021288362829, Average Rank 4.5, ERR 0.9099120249905708
# Average Validation Group Exposure disparity: 0.004901597491086742, Group Asymmetric disparity: 0.009077826363616849
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.9533437866125561, DCG 41.806329652443836, Average Rank 4.5, ERR 0.905143981651789
# Average Validation Group Exposure disparity: 0.0046551376895553, Group Asymmetric disparity: 0.00887717190675613
# Epoch 4, Average Validation: NDCG: 0.9554092714139127, DCG 41.91619945673508, Average Rank 4.5, ERR 0.9065127940799375
# Average Validation Group Exposure disparity: 0.004700480324686762, Group Asymmetric disparity: 0.009296234333683907
# {'ndcg': 0.9564055911861754, 'dcg': 41.948182085862136, 'avg_rank': 4.5, 'err': 0.9125655746635747, 'avg_group_disparity': 0.004798982923307394, 'avg_group_asym_disparity': 0.009465696857076688}
# Learnt model for lambda=7 has model weights as [2.606799364089966, 1.1083192825317383]
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:8
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.827921167634628, DCG 36.52022019696175, Average Rank 4.5, ERR 0.7072043467962249
# Average Validation Group Exposure disparity: 0.012617973284686746, Group Asymmetric disparity: 0.003781708500809413
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.9427771046417314, DCG 41.37411936539901, Average Rank 4.5, ERR 0.8887459784312576
# Average Validation Group Exposure disparity: 0.004524630075139715, Group Asymmetric disparity: 0.008450976458437311
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.926250791733194, DCG 40.70133707544043, Average Rank 4.5, ERR 0.8609878952607004
# Average Validation Group Exposure disparity: 0.004540487406958309, Group Asymmetric disparity: 0.006997790274441521
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.9419459694733949, DCG 41.330022862406324, Average Rank 4.5, ERR 0.8846634445000758
# Average Validation Group Exposure disparity: 0.004698739651638235, Group Asymmetric disparity: 0.007881137861601651
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.9426426462986173, DCG 41.385230328536494, Average Rank 4.5, ERR 0.8895574496111773
# Average Validation Group Exposure disparity: 0.004625522714983471, Group Asymmetric disparity: 0.007535388754694922
# Epoch 4, Average Validation: NDCG: 0.9421532357598019, DCG 41.36645920190952, Average Rank 4.5, ERR 0.8858044998940835
# Average Validation Group Exposure disparity: 0.004630199291418733, Group Asymmetric disparity: 0.008565483280816364
# {'ndcg': 0.9434599824843845, 'dcg': 41.411254142627115, 'avg_rank': 4.5, 'err': 0.8875010520008305, 'avg_group_disparity': 0.00471773844035585, 'avg_group_asym_disparity': 0.008508492127258448}
# Learnt model for lambda=8 has model weights as [2.152127981185913, 0.809484601020813]
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:10
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.9000464232037997, DCG 39.59857652683448, Average Rank 4.5, ERR 0.8321540001577429
# Average Validation Group Exposure disparity: 0.009516523078366843, Group Asymmetric disparity: 0.007991568264826731
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.9455022813129765, DCG 41.48225877271304, Average Rank 4.5, ERR 0.8909940266826468
# Average Validation Group Exposure disparity: 0.004540790101200304, Group Asymmetric disparity: 0.00822565991476935
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.9384654662817781, DCG 41.18186222899934, Average Rank 4.5, ERR 0.8815860587977419
# Average Validation Group Exposure disparity: 0.004742940442863345, Group Asymmetric disparity: 0.0085245922000521
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.9405585131696007, DCG 41.292012368200034, Average Rank 4.5, ERR 0.8852536730776969
# Average Validation Group Exposure disparity: 0.004928420509746278, Group Asymmetric disparity: 0.008215324535091847
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.944673189066325, DCG 41.466317274888745, Average Rank 4.5, ERR 0.8913351945392242
# Average Validation Group Exposure disparity: 0.0045805097909625185, Group Asymmetric disparity: 0.007623925145568077
# Epoch 4, Average Validation: NDCG: 0.9409753606467746, DCG 41.31533056801607, Average Rank 4.5, ERR 0.8858116164650204
# Average Validation Group Exposure disparity: 0.004776297637947669, Group Asymmetric disparity: 0.008892191543051537
# {'ndcg': 0.9430292215113764, 'dcg': 41.3872537191302, 'avg_rank': 4.5, 'err': 0.8868756766980888, 'avg_group_disparity': 0.004690839554997553, 'avg_group_asym_disparity': 0.007578949955904011}
# Learnt model for lambda=10 has model weights as [2.166402816772461, 0.7476701736450195]
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:15
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.7876870964000331, DCG 34.80569510220762, Average Rank 4.5, ERR 0.6483243921871241
# Average Validation Group Exposure disparity: 0.013087229387692965, Group Asymmetric disparity: 0.0012057618045983806
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.9155018028810208, DCG 40.2379771893235, Average Rank 4.5, ERR 0.8464851403037832
# Average Validation Group Exposure disparity: 0.004626448182824661, Group Asymmetric disparity: 0.005013524404400212
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.9180643717236545, DCG 40.344370949034776, Average Rank 4.5, ERR 0.8453931623270833
# Average Validation Group Exposure disparity: 0.0048577776439987265, Group Asymmetric disparity: 0.0056715692270477265
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.9237843751901448, DCG 40.58866041997499, Average Rank 4.5, ERR 0.8586450601869079
# Average Validation Group Exposure disparity: 0.00475274510536719, Group Asymmetric disparity: 0.0060684679728381895
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.9190713847571672, DCG 40.37528010966328, Average Rank 4.5, ERR 0.8495479941574466
# Average Validation Group Exposure disparity: 0.0047308133177384505, Group Asymmetric disparity: 0.005622316413692651
# Epoch 4, Average Validation: NDCG: 0.9172714937805633, DCG 40.27636214448285, Average Rank 4.5, ERR 0.8472870882383652
# Average Validation Group Exposure disparity: 0.004660034322316658, Group Asymmetric disparity: 0.005952755394523417
# {'ndcg': 0.9153694244647471, 'dcg': 40.2314067027626, 'avg_rank': 4.5, 'err': 0.845541101071879, 'avg_group_disparity': 0.004407956229929573, 'avg_group_asym_disparity': 0.005129089108210773}
# Learnt model for lambda=15 has model weights as [1.4490128755569458, 0.3418605327606201]
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:20
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.8310387090175106, DCG 36.664724475384965, Average Rank 4.5, ERR 0.712526520976142
# Average Validation Group Exposure disparity: 0.013034378831148226, Group Asymmetric disparity: 0.002135559340695933
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.866761236394117, DCG 38.15479812932941, Average Rank 4.5, ERR 0.7711330399596354
# Average Validation Group Exposure disparity: 0.006828208652407436, Group Asymmetric disparity: 0.004495089917979438
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.8700149918499163, DCG 38.31125233769428, Average Rank 4.5, ERR 0.7735552014697101
# Average Validation Group Exposure disparity: 0.0073426358736001455, Group Asymmetric disparity: 0.002383604005264836
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.8805458781379413, DCG 38.764961445966065, Average Rank 4.5, ERR 0.7903017850536611
# Average Validation Group Exposure disparity: 0.00642743378949484, Group Asymmetric disparity: 0.0036682706436203215
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.883482567325901, DCG 38.90099298639045, Average Rank 4.5, ERR 0.7961266290208527
# Average Validation Group Exposure disparity: 0.006236651144525948, Group Asymmetric disparity: 0.0026819909094438067
# Epoch 4, Average Validation: NDCG: 0.8777361326224933, DCG 38.65459591541307, Average Rank 4.5, ERR 0.7831861111020327
# Average Validation Group Exposure disparity: 0.006868603459987798, Group Asymmetric disparity: 0.003915577881421289
# {'ndcg': 0.8797653824609419, 'dcg': 38.74220834716325, 'avg_rank': 4.5, 'err': 0.7910585142836459, 'avg_group_disparity': 0.006248681888850559, 'avg_group_asym_disparity': 0.0028558203944877908}
# Learnt model for lambda=20 has model weights as [0.7682244181632996, 0.1818426102399826]
# Starting training with the following config
# Learning rate 0.1, Weight decay 0.0, Sample size 10
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:25
# Training....
# Evaluating on validation set: iteration 0/100 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.8047391994000617, DCG 35.51698090618843, Average Rank 4.5, ERR 0.6725583408237392
# Average Validation Group Exposure disparity: 0.011772395893615846, Group Asymmetric disparity: 0.0013491063334325614
# Training....
# LR is set to 0.05
# Evaluating on validation set: iteration 0/100 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.9009344927479447, DCG 39.60516679778009, Average Rank 4.5, ERR 0.8190615837052533
# Average Validation Group Exposure disparity: 0.005190169105411469, Group Asymmetric disparity: 0.005777559932854401
# Training....
# LR is set to 0.025
# Evaluating on validation set: iteration 0/100 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.8952690951652365, DCG 39.370427773580744, Average Rank 4.5, ERR 0.8176761619433699
# Average Validation Group Exposure disparity: 0.005574387380823293, Group Asymmetric disparity: 0.0033162268983939216
# Training....
# LR is set to 0.0125
# Evaluating on validation set: iteration 0/100 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.8976892361728352, DCG 39.471819453243846, Average Rank 4.5, ERR 0.8165077908982407
# Average Validation Group Exposure disparity: 0.005053495892923472, Group Asymmetric disparity: 0.00353902213843717
# Training....
# LR is set to 0.00625
# Evaluating on validation set: iteration 0/100 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.8879006828327957, DCG 39.081989143098696, Average Rank 4.5, ERR 0.8015935459716071
# Average Validation Group Exposure disparity: 0.005582876505928211, Group Asymmetric disparity: 0.0036928165822598465
# Epoch 4, Average Validation: NDCG: 0.884941747374969, DCG 38.909799137661146, Average Rank 4.5, ERR 0.7970152004290307
# Average Validation Group Exposure disparity: 0.007685639427990851, Group Asymmetric disparity: 0.003200447491787297
# {'ndcg': 0.8873945612428351, 'dcg': 39.05144886758449, 'avg_rank': 4.5, 'err': 0.802598457126782, 'avg_group_disparity': 0.00602352566592703, 'avg_group_asym_disparity': 0.00325976784752586}
# Learnt model for lambda=25 has model weights as [0.8945045471191406, 0.16544456779956818]

# %%
#scatter plot
for i, model_weights in enumerate(model_params_list):
    plt.scatter(model_weights[0], model_weights[1], label=lambdas_list[i])
    plt.annotate('{}'.format(lambdas_list[i]), (model_weights[0], model_weights[1]))

# %%
model_params_list_updated = np.array(model_params_list)[np.array([0,1,3,4,6,7])]
lambdas_list_updated = np.array(lambdas_list)[np.array([0,1,3,4,6,7])]
pprint(list(zip(lambdas_list_updated, model_params_list_updated)))
# Out:
# [(0, array([3.92408657, 3.33153176])),
#  (1, array([3.88519573, 3.03443336])),
#  (5, array([2.95582175, 1.62346137])),
#  (10, array([1.7334075 , 0.39891949])),
#  (20, array([1.10431325, 0.29886863])),
#  (25, array([0.96943235, 0.17144544]))]

# %%
fig= plt.figure(figsize=(7, 4))
ax1 = fig.add_subplot(121)
im = ax1.contourf(w2s, w1s, Z, cmap=cm.PuBu)
ax1.xaxis.set_label_position('bottom')
ax1.yaxis.set_label_position('left')
ax1.tick_params(labelbottom=True, labeltop=False, labelleft=True , labelright=False )
ax1.set_xlabel(r'$\theta_1$', fontsize=16)
ax1.set_ylabel(r'$\theta_2$', fontsize=16)
ax1.set_title('(a) NDCG', y=-0.35)
cbaxes = fig.add_axes([0.02, 0.20, 0.02, 0.6])
fig.colorbar(im, ax=ax1, cax=cbaxes)
cbaxes.yaxis.set_label_position('left')
cbaxes.yaxis.set_ticks_position('left')
ax1.axis('equal')

ax2 = fig.add_subplot(122)
from matplotlib import colors
im = ax2.contourf(w2s, w1s, Z2, cmap=cm.Reds)
ax2.xaxis.set_label_position('bottom')
ax2.yaxis.set_label_position('left')
ax2.tick_params(labelbottom=True, labeltop=False, labelleft=True , labelright=False )
ax2.set_xlabel(r'$\theta_1$', fontsize=16)
ax2.set_ylabel(r'$\theta_2$', fontsize=16)
ax2.set_title('(b) Disparity', y=-0.35)
cbaxes = fig.add_axes([0.92, 0.20, 0.02, 0.6])

ax2.axis('equal')

fig.colorbar(im, ax=ax2, cax=cbaxes)
cbaxes.yaxis.set_label_position('right')
cbaxes.yaxis.set_ticks_position('right')

ax1.scatter(model_params_list_updated[:,0], model_params_list_updated[:,1], marker='+', color='k')
ax2.scatter(model_params_list_updated[:,0], model_params_list_updated[:,1], marker='+', color='k')
texts = []
texts2 = []

ax1.plot([0, 5], [0, 5], ls="--", c=".1", alpha=0.2)
ax2.plot([0, 5], [0, 5], ls="--", c=".1", alpha=0.2)
    
for i in range(len(lambdas_list_updated)):
    texts.append(ax1.text(model_params_list_updated[i,0], model_params_list_updated[i,1], 
                          r"$\lambda$="+str(lambdas_list_updated[i]), fontsize=16))
    texts2.append(ax2.text(model_params_list_updated[i,0], model_params_list_updated[i,1], 
                           r"$\lambda$="+str(lambdas_list_updated[i]), fontsize=16))
from adjustText import adjust_text
adjust_text(texts, ax=ax1)#, x=w1s, y=w2s)
adjust_text(texts2, ax=ax2)#,  x=w1s, y=w2s)
ax1.set_aspect('equal', adjustable='box')
ax2.set_aspect('equal', adjustable='box')
ax1.set_xlim(0.0, 5.0)
ax2.set_xlim(0.0, 5.0)
ax1.set_ylim(0.0, 5.0)
ax2.set_ylim(0.0, 5.0)
ax1.set_aspect('equal', adjustable='box')
ax2.set_aspect('equal', adjustable='box')
    
#fig.tight_layout()
plt.savefig("plots/group_fairness_synthetic_contourf.pdf", bbox_inches='tight')
plt.show()

# %%
from itertools import permutations 
from scipy.optimize import linprog

# %%
def assign_groups(groups):
    G = [[], []]
    for i in range(len(groups)):
        G[groups[i]].append(i)
    return G


def fair_rank(relevances, groups ,lmda = 1):
    n = len(relevances)
    pos_bias = vvector(n)
    G = assign_groups(groups)
    n_g, n_i = 0, 0
    n_g += (len(G)-1)*len(G)
    n_c = n**2 + n_g 
    
    
    c = np.ones(n_c)
    c[:n**2] *= -1
    c[n**2:] *= lmda
    A_eq = []
    #For each Row
    for i in range(n):
        A_temp = np.zeros(n_c)
        A_temp[i*n:(i+1)*n] = 1
        assert(sum(A_temp)==n)
        A_eq.append(A_temp)
        c[i*n:(i+1)*n] *= relevances[i]

    #For each coloumn
    for i in range(n):
        A_temp = np.zeros(n_c)
        A_temp[i:n**2:n] = 1
        assert(sum(A_temp)==n)
        A_eq.append(A_temp)
        #Optimization 
        c[i:n**2:n] *= pos_bias[i] 
    b_eq = np.ones(n*2) 
    A_eq = np.asarray(A_eq)
    bounds = [(0,1) for _ in range(n**2)] + [(0,None) for _ in range(n_g+n_i)]
    
    
    A_ub = []
    b_ub = np.zeros(n_g)
    sum_rels = []
    for group in G:
        #Avoid devision by zero
        sum_rel = np.max([np.sum(np.asarray(relevances)[group]), 0.01])
        sum_rels.append(sum_rel)
    comparisons = list(permutations(np.arange(len(G)),2))
    j = 0
    for a,b in comparisons:
        f = np.zeros(n_c)
        if len(G[a]) > 0 and len(G[b])>0 and sum_rels[a]/len(G[a]) >= sum_rels[b]/len(G[b]):
            for i in range(n):
                tmp1 = len(G[a]) / sum_rels[a] if i in G[a] else 0 
                tmp2 = len(G[b]) / sum_rels[b] if i in G[b] else 0 
                #f[i*n:(i+1)*n] *= max(0, sign*(tmp1 - tmp2))
                f[i*n:(i+1)*n] =  (tmp1 - tmp2)
            for i in range(n):
                f[i:n**2:n] *= pos_bias[i]
            f[n**2+j] = -1
        j += 1
        A_ub.append(f)

    res = linprog(c, A_eq=A_eq, b_eq=b_eq, A_ub=A_ub, b_ub=b_ub, bounds=bounds, 
                                  method = "interior-point")#, options=dict(tol=1e-12),)
    if res.success is False:
        print("Constraint not satisfied!!")
    probabilistic_ranking = np.reshape(res.x[:n**2],(n,n))
    return probabilistic_ranking, res, res.fun

# %%
def get_best_rankmatrix(true_rel_vector):
    N = len(true_rel_vector)
    bestranking = np.zeros((N,N))
    bestr = np.argsort(true_rel_vector)[::-1]
    for i in range(N):
        bestranking[bestr[i], i] = 1
    return bestranking

#returns DCG value
def get_DCG(ranking, relevances, vvector):
    N = len(relevances)
    return np.matmul(np.matmul(2**relevances-1, ranking), vvector.transpose())

def get_ndcg(ranking, relevances, vvector):
    bestr = get_best_rankmatrix(relevances)
    return get_DCG(ranking, relevances, vvector)/get_DCG(bestr, relevances, vvector)


def get_fairness_loss(ranking, relevances, vvector, groups):
    avg_rels = [np.mean(relevances[groups==i]) for i in range(2)]
    sign = +1 if avg_rels[0] > avg_rels[1] else -1
    exposures = np.matmul(ranking, vvector)
    group_avg_exposures = [np.mean(exposures[groups==0]), np.mean(exposures[groups==1])]
    #print(avg_rels, sign, exposures, group_avg_exposures)
    loss = max([0.0, sign*(group_avg_exposures[0]/avg_rels[0] - group_avg_exposures[1]/avg_rels[1])])
    return loss

def get_avg_fairness_loss(dr, predicted_rels, vvector, lmbda):
    feats, rel = dr.data
    test_losses = []
    for i in range(len(rel)):
        N = len(rel[i])
        pred_rels = predicted_rels[i]
        groups = np.array(feats[i][:,0], dtype=np.int)
        P, _, _ = fair_rank(pred_rels, groups, lmbda )
        test_loss = get_fairness_loss(P, rel[i], vvector[:N], groups)
        test_losses.append(test_loss)
    return np.mean(test_losses)

vvector = lambda N: 1. / np.log2(2 + np.arange(N))

# %%
# Linear regression
from sklearn import linear_model
model = linear_model.LinearRegression(fit_intercept=False, normalize=False)
feats, rel = dr.data
feats = np.array([item for sublist in feats for item in sublist])
rel = np.array([item for sublist in rel for item in sublist])
model.fit(feats[:, 1:], rel)
# predictions on validation
feats, rel = vdr.data
se_sum = 0
length = 0
predicted_rels = []
for i, query in enumerate(feats):
    rel_pred = model.predict(query[:,1:])
    predicted_rels.append(rel_pred)
    se_sum += np.sum((rel_pred - rel[i])**2)
    length += len(rel[i])
print(se_sum/ length)
# Out:
# 0.5108247274310144

# %%
print(model.coef_)
w1, w2 = model.coef_
print(eval_params(w1, w2, vdr, True))
print(get_avg_fairness_loss(vdr, predicted_rels, vvector(200), 0.0))
# Out:
# [1.17587743 0.72523981]
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_util.py:704: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   warn(redundancy_warning, OptimizeWarning)
# {'ndcg': 0.9799779011718815, 'dcg': 42.95000418605716, 'avg_rank': 4.5, 'err': 0.9458127103682267, 'avg_residuals': 0.2571649453670865, 'avg_rsq': 0.4397898789118018, 'avg_l1_dists': 1.09594726509538, 'scale_inv_mse': 0.34167615537571655, 'asymmetric_disparity': 0.020275933615568797, 'avg_group_disparity': 0.00559422884466421, 'avg_group_asym_disparity': 0.01198083210876891}
# 0.011980824449562215

# %%
# # for each lambda
# now for each query, estimate all relevances
# we find a fair ranking, find it's loss w.r.t true relevances
lmbdas = np.linspace(0, 6, 20)

plt_data = np.zeros((len(lmbdas), 2))

for j, lmbda in enumerate(lmbdas):
    test_losses = []
    test_ndcgs = []
    
    for i in range(len(predicted_rels)):
        true_rels = rel[i]
        pred_rels = predicted_rels[i]
        groups = np.array(feats[i][:, 0], dtype=np.int)
        n = len(groups)
        
        P, _, _ = fair_rank(pred_rels, groups, lmbda)
        
        test_loss = get_fairness_loss(P, true_rels, vvector(n), groups)
        test_losses.append(test_loss)
        
        test_ndcg = get_ndcg(P, true_rels, vvector(n))
        test_ndcgs.append(test_ndcg)
        
    plt_data[j] = [np.mean(test_ndcgs), np.mean(test_losses)]
        
        
    print("Lambda: {}, Average Test Fairness Loss: {}, Average Test NDCG: {}".format(lmbda, 
                                                     np.mean(test_losses), np.mean(test_ndcgs)))

plt.scatter(plt_data[:, 0], plt_data[:, 1])
# Out:
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_util.py:704: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   warn(redundancy_warning, OptimizeWarning)
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Lambda: 0.0, Average Test Fairness Loss: 0.011980824449562215, Average Test NDCG: 0.9799779030487127
# Lambda: 0.3157894736842105, Average Test Fairness Loss: 0.010636178713741442, Average Test NDCG: 0.9811117979966874
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_ip.py:273: OptimizeWarning: Solving system with option 'sym_pos':True failed. It is normal for this to happen occasionally, especially as the solution is approached. However, if you see this frequently, consider setting option 'sym_pos' to False.
#   OptimizeWarning)
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_ip.py:285: OptimizeWarning: Solving system with option 'sym_pos':False failed. This may happen occasionally, especially as the solution is approached. However, if you see this frequently, your problem may be numerically challenging. If you cannot improve the formulation, consider setting 'lstsq' to True. Consider also setting `presolve` to True, if it is not already.
#   OptimizeWarning)
# Lambda: 0.631578947368421, Average Test Fairness Loss: 0.01021731842804904, Average Test NDCG: 0.9826527811584204
# Lambda: 0.9473684210526315, Average Test Fairness Loss: 0.00964468950375182, Average Test NDCG: 0.9827095417844451
# Lambda: 1.263157894736842, Average Test Fairness Loss: 0.010271297373544404, Average Test NDCG: 0.981490801976816
# Lambda: 1.5789473684210527, Average Test Fairness Loss: 0.010454523307789313, Average Test NDCG: 0.9780777748031331
# Lambda: 1.894736842105263, Average Test Fairness Loss: 0.013163543309313196, Average Test NDCG: 0.9728978705910145
# Lambda: 2.2105263157894735, Average Test Fairness Loss: 0.019338293626949797, Average Test NDCG: 0.9636220222132407
# Lambda: 2.526315789473684, Average Test Fairness Loss: 0.024783012292317146, Average Test NDCG: 0.9567725140117784
# Lambda: 2.8421052631578947, Average Test Fairness Loss: 0.0306878595785783, Average Test NDCG: 0.9521330796686261
# Lambda: 3.1578947368421053, Average Test Fairness Loss: 0.037206015859155894, Average Test NDCG: 0.9451950794676636
# Lambda: 3.4736842105263155, Average Test Fairness Loss: 0.03824156610595241, Average Test NDCG: 0.9424623577388548
# Lambda: 3.789473684210526, Average Test Fairness Loss: 0.03905402847294781, Average Test NDCG: 0.9389551527372294
# Lambda: 4.105263157894736, Average Test Fairness Loss: 0.04044679841999588, Average Test NDCG: 0.9373467915829985
# Lambda: 4.421052631578947, Average Test Fairness Loss: 0.042021551273892725, Average Test NDCG: 0.9363972047559881
# Lambda: 4.7368421052631575, Average Test Fairness Loss: 0.04202155128102876, Average Test NDCG: 0.9361812390064356
# Lambda: 5.052631578947368, Average Test Fairness Loss: 0.042021551287038134, Average Test NDCG: 0.9359505384361452
# Lambda: 5.368421052631579, Average Test Fairness Loss: 0.0420215512933816, Average Test NDCG: 0.9355426483418089
# Lambda: 5.684210526315789, Average Test Fairness Loss: 0.0422693492900986, Average Test NDCG: 0.9353938818210004
# Lambda: 6.0, Average Test Fairness Loss: 0.042269349311067, Average Test NDCG: 0.9350463649035798

# %%
model_params_list
# Out:
# [[3.924086570739746, 3.3315317630767822],
#  [3.885195732116699, 3.034433364868164],
#  [3.9238085746765137, 2.6752028465270996],
#  [2.9558217525482178, 1.623461365699768],
#  [1.7334074974060059, 0.3989194929599762],
#  [1.0354145765304565, 0.2823873460292816],
#  [1.1043132543563843, 0.2988686263561249],
#  [0.9694323539733887, 0.17144544422626495]]

# %%
plt_data_2 = []
plt_data_3 = []
for i, (w1, w2) in enumerate(model_params_list):
    if i == 0:
        result = eval_params(w1, w2, vdr, det=True)
        plt_data_2.append([result["ndcg"], result["avg_group_asym_disparity"]])
    result = eval_params(w1, w2, vdr, det=False)
    plt_data_2.append([result["ndcg"], result["avg_group_asym_disparity"]])
    result = eval_params(w1, w2, vdr, det=True)
    plt_data_3.append([result["ndcg"], result["avg_group_asym_disparity"]])
# Out:
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
plt_data_2 = np.array(plt_data_2)

# %%
plt_data_2 = np.array(plt_data_2)
plt_data_3 = np.array(plt_data_3)

# %%
plt.scatter(plt_data[:, 0], plt_data[:, 1])
plt.scatter(plt_data_2[:, 0], plt_data_2[:, 1])
plt.scatter(plt_data_3[0, 0], plt_data_3[0, 1])

# %%
CustomLinearModel(D=3, fix_weight_dim=0)
# Out:
# CustomLinearModel(
#   (w): Linear(in_features=2, out_features=1, bias=False)
# )

# %%
from zehlike import *
model = CustomLinearModel(D=3, fix_weight_dim=0)
args.lr = [0.001]
args.lambda_reward = 1.0
plt_data_4 = []
lambdas = [0.0, 0.1, 1.0, 10, 100, 1000, 10000, 100000, 1000000]
args.weight_decay = [0.0]
args.epochs = [10]
args.evaluate_interval = 100
disparities_mat = np.zeros((len(lambdas), 1))
ndcg_mat = np.zeros((len(lambdas), 1))
for i, lg in enumerate(lambdas):
    args.lambda_group_fairness = lg
    model = demographic_parity_train(model, dr, vdr, vvector(200), args)
    results = evaluate_model(
            model,
            vdr,
            fairness_evaluation=False,
            group_fairness_evaluation=True,
            deterministic=True,
            args=args,
            num_sample_per_query=100)
    plt_data_4.append([results["ndcg"], results["avg_group_asym_disparity"]])
    ndcg_mat[i, 0], disparities_mat[i,0] = results["ndcg"], results["avg_group_asym_disparity"]
# Out:
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
print(plt_data_4)
# Out:
# [[0.9775540660032678, 0.011750728104522606], [0.9776186607439318, 0.01222295311012128], [0.9779368916110708, 0.011996044226649339], [0.977936891611071, 0.011996044226649336], [0.9777036200596969, 0.011809356405740911], [0.9773650073320397, 0.012381329467024606], [0.9781441000147226, 0.013065952144585254], [0.9779073164212629, 0.013303760960345681], [0.9767926000752684, 0.014085082086661132]]

# %%
plt_data_4 = np.array(plt_data_4)

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 75

plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = 10, 6
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 10

plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = "serif"
plt.rcParams['font.serif'] = "cm"
plt.rcParams[
    'text.latex.preamble'] = r"\usepackage{subdepth}, \usepackage{type1cm}"

# %%
def ndcg_vs_disparity_plot(plt_data_mats, names, join=False, ranges=None):
    plt.figure(figsize=(5.5,3.65))
    if ranges:
        plt.xlim(ranges[0])
        plt.ylim(ranges[1])
    for i, plt_data_mat in enumerate(plt_data_mats):
        if not join:
            plt.scatter(
                plt_data_mats[i][:, 0],
                plt_data_mats[i][:, 1],
                marker="+",
                label=names[i])
        else:
            plt.plot(
                plt_data_mats[i][:, 0],
                plt_data_mats[i][:, 1],
                marker="+",
                linestyle='--',
                label=names[i], alpha=0.75)
    plt.legend(fontsize=12)
    plt.title("(c) Utility-Fairness trade-off",y=-0.30)
    plt.xlabel("NDCG", fontsize=16)
    plt.ylabel(r'$\hat{\mathcal{D}}_{\rm group}$', fontsize=16)
    plt.grid()
    plt.savefig('./plots/toy_tradeoff.pdf', bbox_inches='tight')
    plt.show()

# %%
ndcg_vs_disparity_plot([plt_data, plt_data_2,plt_data_4],
                      ["Post-Processing ($\lambda \in [0, 6]$)",
                      "Our Method ($\lambda \in [0,25]$)", 
                      "Zehlike et al. ($\lambda \in [0, 10^6]$)"],
                      join=True)
