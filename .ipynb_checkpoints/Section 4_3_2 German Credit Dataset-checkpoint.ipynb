# %% [markdown]
# # Real Dataset Experiment (German Credit Dataset-- Group Fairness)
# Generate the dataset for LTR setting

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib import colors, ticker, cm

from pprint import pprint
from progressbar import progressbar

# %matplotlib inline

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf', 'png')
plt.rcParams['savefig.dpi'] = 75

plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = 10, 6
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 2.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 14

plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = "serif"
plt.rcParams['font.serif'] = "cm"
plt.rcParams['text.latex.preamble'] = r"\usepackage{subdepth}, \usepackage{type1cm}"

# %%
cd ..
# Out:
# /home/ashudeep/projects/fairness/fair_svmrank

# %%
from train_yahoo_dataset import on_policy_training
from YahooDataReader import YahooDataReader
import torch
from models import NNModel, LinearModel
from evaluation import evaluate_model

# %%
# read data 
import pickle as pkl
dr = YahooDataReader(None)
dr.data = pkl.load(open("GermanCredit/german_train_rank.pkl", "rb"))
vdr = YahooDataReader(None)
vdr.data = pkl.load(open("GermanCredit/german_test_rank.pkl","rb"))

# %%
class Namespace:
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)
args = Namespace(conditional_model=True, gpu_id=None, progressbar=True, evaluate_interval=250, input_dim=29, 
                 eval_rank_limit=1000,
                fairness_version="asym_disparity", entropy_regularizer=0.0, save_checkpoints=False, num_cores=1,
                pooling='concat_avg', dropout=0.0, hidden_layer=8, summary_writing=False, 
                 group_fairness_version="asym_disparity",early_stopping=False, lr_scheduler=False, 
                 validation_deterministic=False, evalk=1000, reward_type="ndcg", baseline_type="value", 
                 use_baseline=True, entreg_decay=0.0, skip_zero_relevance=True, eval_temperature=1.0, optimizer="Adam",
                clamp=False)
torch.set_num_threads(args.num_cores)
args.progressbar = False 

args.group_feat_id = 3

# %%
model_params_list = []
lambdas_list = [0.0, 0.1, 1.0, 10.0, 12.0, 15.0, 20.0, 25.0, 50.0, 100.0]
plt_data_pl = np.zeros((len(lambdas_list)+1, 2))
for i, lgroup in enumerate(lambdas_list):
        torch.set_num_threads(args.num_cores)
        args.lambda_reward = 1.0
        args.lambda_ind_fairness = 0.0
        args.lambda_group_fairness = lgroup
        
        args.lr = 0.001
        args.epochs = 10
        args.progressbar = False
        args.weight_decay = 0.0
        args.sample_size = 25
        args.optimizer = "Adam"

        model = LinearModel(D=args.input_dim)

        model = on_policy_training(dr, vdr, model, args=args)
        if i == 0:
            results = evaluate_model(model, vdr, fairness_evaluation=False, group_fairness_evaluation=True, 
                                 deterministic=True, args=args, num_sample_per_query=20)
            print(results)
            plt_data_pl[0] = [results["ndcg"], results["avg_group_asym_disparity"]]
        results = evaluate_model(model, vdr, fairness_evaluation=False, group_fairness_evaluation=True, 
                                 deterministic=False, args=args, num_sample_per_query=20)
        print(results)
        model_params_list.append(model.w.weight.data.tolist()[0])
        print("Learnt model for lambda={} has model weights as {}".format(lgroup, model_params_list[-1]))
        plt_data_pl[i+1] = [results["ndcg"], results["avg_group_asym_disparity"]]
# Out:
# Starting training with the following config
# Learning rate 0.001, Weight decay 0.0, Sample size 25
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:0.0
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.6929591151625566, DCG 1.772368249173742, Average Rank 4.5284615384615385, ERR 0.06660219570566596
#
# Averages of last 1000 rewards: 0.6942634649402132, ndcgs: 0.6942634649402132, dcgs: 1.6786001988714567
# Evaluating on validation set: iteration 250/500 of epoch 0
# Epoch 0, Average Validation: NDCG: 0
# Evaluating on validation set: iteration 250/500 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.7905106650261068, DCG 2.0061385329718524, Average Rank 3.4582051282051283, ERR 0.08347803121696869
# Average Validation Group Exposure disparity: 0.6975855455987903, Group Asymmetric disparity: 0.005680805401821269
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.7995333766177172, DCG 2.0285422373997877, Average Rank 3.4751282051282053, ERR 0.08542470783239678
# Average Validation Group Exposure disparity: 0.7389146439891234, Group Asymmetric disparity: 0.007113518776815693
#
# Averages of last 1000 rewards: 0.8175195924514341, ndcgs: 0.8175195924514341, dcgs: 1.9996210812150053
# Evaluating on validation set: iteration 250/500 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.804469285299756, DCG 2.0385835660003773, Average Rank 3.404102564102564, ERR 0.08608791177285326
# Average Validation Group Exposure disparity: 0.7394187143192977, Group Asymmetric disparity: 0.00726549425340768
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 5
# Epoch 5, Average Validation: NDCG: 0.8049770914516203, DCG 2.036877106190847, Average Rank 3.404358974358974, ERR 0.08592783319408938
# Average Validation Group Exposure disparity: 0.6942169535631227, Group Asymmetric disparity: 0.009522936101338376
#
# Averages of last 1000 rewards: 0.8193231363677169, ndcgs: 0.8193231363677169, dcgs: 2.023615627162526
# Evaluating on validation set: iteration 250/500 of epoch 5
# Epoch 5, Average Validation: NDCG: 0.8031268709844555, DCG 2.0343790804500745, Average Rank 3.4164102564102565, ERR 0.08574468190265146
# Average Validation Group Exposure disparity: 0.7401192793443775, Group Asymmetric disparity: 0.008008200538528784
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 6
# Epoch 6, Average Validation: NDCG: 0.8094869447857131, DCG 2.0532055354253957, Average Rank 3.353846153846154, ERR 0.08715539441735498
# Average Validation Group Exposure disparity: 0.7245117822650481, Group Asymmetric disparity: 0.008652454902329779
#
# Averages of last 1000 rewards: 0.8163473735108384, ndcgs: 0.8163473735108384, dcgs: 1.9798737984934505
# Evaluating on validation set: iteration 250/500 of epoch 6
# Epoch 6, Average Validation: NDCG: 0.8074067658772414, DCG 2.0471905792100613, Average Rank 3.376153846153846, ERR 0.08670252598454585
# Average Validation Group Exposure disparity: 0.7432897995638491, Group Asymmetric disparity: 0.009420810169643697
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 7
# Epoch 7, Average Validation: NDCG: 0.8151993214304302, DCG 2.0638150066603598, Average Rank 3.3415384615384616, ERR 0.08802617664889631
# Average Validation Group Exposure disparity: 0.7648381376474062, Group Asymmetric disparity: 0.008943021778609134
#
# Averages of last 1000 rewards: 0.8253666436674002, ndcgs: 0.8253666436674002, dcgs: 2.0041425816507634
# Evaluating on validation set: iteration 250/500 of epoch 7
# Epoch 7, Average Validation: NDCG: 0.8129839304009617, DCG 2.057240733707107, Average Rank 3.345897435897436, ERR 0.08746802825418808
# Average Validation Group Exposure disparity: 0.7412893565611267, Group Asymmetric disparity: 0.0111333881321784
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 8
# Epoch 8, Average Validation: NDCG: 0.810998775789161, DCG 2.0523704836878056, Average Rank 3.3515384615384614, ERR 0.08709919925771642
# Average Validation Group Exposure disparity: 0.7445721963682892, Group Asymmetric disparity: 0.009066428085918576
#
# Averages of last 1000 rewards: 0.836900522631453, ndcgs: 0.836900522631453, dcgs: 2.0134064321353065
# Evaluating on validation set: iteration 250/500 of epoch 8
# Epoch 8, Average Validation: NDCG: 0.8175368870305141, DCG 2.0668382141077104, Average Rank 3.3466666666666667, ERR 0.08831635735802912
# Average Validation Group Exposure disparity: 0.7411504030697611, Group Asymmetric disparity: 0.010895619660828623
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 9
# Epoch 9, Average Validation: NDCG: 0.8127528048208054, DCG 2.0577774027379996, Average Rank 3.342051282051282, ERR 0.08749032288367382
# Average Validation Group Exposure disparity: 0.7540358749560555, Group Asymmetric disparity: 0.009762901299639795
#
# Averages of last 1000 rewards: 0.851812314121042, ndcgs: 0.851812314121042, dcgs: 2.068857526162843
# Evaluating on validation set: iteration 250/500 of epoch 9
# Epoch 9, Average Validation: NDCG: 0
# Evaluating on validation set: iteration 250/500 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.7757837361628269, DCG 1.9724864368442028, Average Rank 3.632051282051282, ERR 0.08118501431803858
# Average Validation Group Exposure disparity: 0.7309591449736417, Group Asymmetric disparity: 0.002990904320948865
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.7753051750984045, DCG 1.9724576593231515, Average Rank 3.5982051282051284, ERR 0.08104297008390014
# Average Validation Group Exposure disparity: 0.6681624669889963, Group Asymmetric disparity: 0.004834911455339375
#
# Averages of last 1000 rewards: 0.7819159267122052, ndcgs: 0.7819159267122052, dcgs: 1.9260243262799468
# Evaluating on validation set: iteration 250/500 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.7796321351159022, DCG 1.9834893605990183, Average Rank 3.5625641025641026, ERR 0.08187365229902487
# Average Validation Group Exposure disparity: 0.7008870873414756, Group Asymmetric disparity: 0.005495256611231294
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 5
# Epoch 5, Average Validation: NDCG: 0.7885141379323474, DCG 2.0014767798525197, Average Rank 3.5394871794871796, ERR 0.08334612416699586
# Average Validation Group Exposure disparity: 0.7037360833766588, Group Asymmetric disparity: 0.006786811827545154
#
# Averages of last 1000 rewards: 0.794476119949006, ndcgs: 0.794476119949006, dcgs: 1.9508072723421765
# Evaluating on validation set: iteration 250/500 of epoch 5
# Epoch 5, Average Validation: NDCG: 0.7898504555822714, DCG 2.0014101791132966, Average Rank 3.546666666666667, ERR 0.0833393048642666
# Average Validation Group Exposure disparity: 0.6784790566035802, Group Asymmetric disparity: 0.006569365496341704
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 6
# Epoch 6, Average Validation: NDCG: 0.7919596709761002, DCG 2.015400416387298, Average Rank 3.4817948717948717, ERR 0.08433145738012278
# Average Validation Group Exposure disparity: 0.7315235423895718, Group Asymmetric disparity: 0.006799873341286162
#
# Averages of last 1000 rewards: 0.7952070737392337, ndcgs: 0.7952070737392337, dcgs: 1.946586946731385
# Evaluating on validation set: iteration 250/500 of epoch 6
# Epoch 6, Average Validation: NDCG: 0.7987577946018192, DCG 2.02222051871488, Average Rank 3.4602564102564104, ERR 0.084877794699492
# Average Validation Group Exposure disparity: 0.7194160644961434, Group Asymmetric disparity: 0.004503006774747323
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 7
# Epoch 7, Average Validation: NDCG: 0.7971868007525242, DCG 2.0212034828333576, Average Rank 3.442820512820513, ERR 0.08470999994797278
# Average Validation Group Exposure disparity: 0.6960415482899696, Group Asymmetric disparity: 0.004901843342645952
#
# Averages of last 1000 rewards: 0.8115305412663456, ndcgs: 0.8115305412663456, dcgs: 1.9730978066650755
# Evaluating on validation set: iteration 250/500 of epoch 7
# Epoch 7, Average Validation: NDCG: 0.8046823366898578, DCG 2.0386013012869166, Average Rank 3.3956410256410257, ERR 0.08605142803041188
# Average Validation Group Exposure disparity: 0.7004960771122413, Group Asymmetric disparity: 0.005610810406730424
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 8
# Epoch 8, Average Validation: NDCG: 0.7969302506018866, DCG 2.023236224119577, Average Rank 3.459230769230769, ERR 0.08496000847721312
# Average Validation Group Exposure disparity: 0.7076981858899134, Group Asymmetric disparity: 0.007251291311540325
#
# Averages of last 1000 rewards: 0.7993442670289612, ndcgs: 0.7993442670289612, dcgs: 1.9543744680639334
# Evaluating on validation set: iteration 250/500 of epoch 8
# Epoch 8, Average Validation: NDCG: 0.8012102753765433, DCG 2.030091447547917, Average Rank 3.4261538461538463, ERR 0.08543074400583697
# Average Validation Group Exposure disparity: 0.7153487885075984, Group Asymmetric disparity: 0.009944494232303184
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 9
# Epoch 9, Average Validation: NDCG: 0.7986119266943192, DCG 2.0273406180089264, Average Rank 3.4492307692307693, ERR 0.08523590215097823
# Average Validation Group Exposure disparity: 0.6784992246032858, Group Asymmetric disparity: 0.006293790115209705
#
# Averages of last 1000 rewards: 0.8075046870295937, ndcgs: 0.8075046870295937, dcgs: 1.9362414666523002
# Evaluating on validation set: iteration 250/500 of epoch 9
# Epoch 9, Average Validation: NDCG: 0
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 9
# Epoch 9, Average Validation: NDCG: 0.7125341432711559, DCG 1.8172103084856672, Average Rank 4.329487179487179, ERR 0.06993107055743782
# Average Validation Group Exposure disparity: 0.7656005098750494, Group Asymmetric disparity: 0.001815902245576254
#
# Averages of last 1000 rewards: 0.6926474198426793, ndcgs: 0.6926474198426793, dcgs: 1.701717119043135
# Evaluating on validation set: iteration 250/500 of epoch 9
# Epoch 9, Average Validation: NDCG: 0.7095415811247244, DCG 1.8126494328758886, Average Rank 4.3476923076923075, ERR 0.0695548138112459
# Average Validation Group Exposure disparity: 0.736055327138166, Group Asymmetric disparity: 0.0007300838327122383
# Epoch 9, Average Validation: NDCG: 0.7117187626368796, DCG 1.817074869395596, Average Rank 4.310769230769231, ERR 0.06986639745672979
# Average Validation Group Exposure disparity: 0.7249288494077417, Group Asymmetric disparity: 0.0009985399657353366
# {'ndcg': 0.7143494379966758, 'dcg': 1.8195498162636223, 'avg_rank': 4.326153846153846, 'err': 0.07009073480806767, 'avg_group_disparity': 0.7564125559007948, 'avg_group_asym_disparity': 0.0004816211525129599}
# Learnt model for lambda=20.0 has model weights as [-0.04158379137516022, -0.03026745095849037, -0.09387407451868057, -0.01261951494961977, 0.012549391016364098, 0.06701057404279709, -0.004609433934092522, -0.043130163103342056, 0.028981821611523628, 0.025064896792173386, -0.05011613667011261, 0.02895388938486576, 0.055423934012651443, 0.023530948907136917, 0.07135647535324097, -0.16954027116298676, -0.06835298985242844, 0.08265981823205948, -0.08632753789424896, -0.059037987142801285, 0.10812707990407944, 0.12342194467782974, -0.038715921342372894, -0.04336564242839813, -0.13789117336273193, 0.0636923685669899, 0.0007543702377006412, -0.078823022544384, 0.09597992151975632]
# Starting training with the following config
# Learning rate 0.001, Weight decay 0.0, Sample size 25
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:25.0
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.6918223344381772, DCG 1.7691687745337874, Average Rank 4.51974358974359, ERR 0.06629915613775318
# Average Validation Group Exposure disparity: 0.7932948191319124, Group Asymmetric disparity: 0.0009890779919594906
#
# Averages of last 1000 rewards: 0.6834606813038497, ndcgs: 0.6834606813038497, dcgs: 1.6903440390426965
# Evaluating on validation set: iteration 250/500 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.6957741217954166, DCG 1.7800539812192264, Average Rank 4.52051282051282, ERR 0.06724899757962963
# Average Validation Group Exposure disparity: 0.7981155912875414, Group Asymmetric disparity: 0.003441788270171139
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.6959503140840603, DCG 1.7743298630183042, Average Rank 4.53, ERR 0.06680036350230562
# Average Validation Group Exposure disparity: 0.7914662134264185, Group Asymmetric disparity: 0.002349518235847664
#
# Averages of last 1000 rewards: 0.6823813906407553, ndcgs: 0.6823813906407553, dcgs: 1.6731326651982052
# Evaluating on validation set: iteration 250/500 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.6906487821278856, DCG 1.7628912758632242, Average Rank 4.564102564102564, ERR 0.06590833789188053
# Average Validation Group Exposure disparity: 0.7402815347644686, Group Asymmetric disparity: 1.6216466188501145e-05
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.6931266531675289, DCG 1.7719145575599577, Average Rank 4.532564102564103, ERR 0.06658538082278045
# Average Validation Group Exposure disparity: 0.8052554781210862, Group Asymmetric disparity: 0.0008328931646967086
#
# Averages of last 1000 rewards: 0.6752794781661924, ndcgs: 0.6752794781661924, dcgs: 1.6645772404464725
# Evaluating on validation set: iteration 250/500 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.6896702307026026, DCG 1.7642950030980125, Average Rank 4.6, ERR 0.06611940513507811
# Average Validation Group Exposure disparity: 0.7845556947786421, Group Asymmetric disparity: 0.0010097701420422732
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 3
# Epoch 3, Average Validation: NDCG: 0
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 9
# Epoch 9, Average Validation: NDCG: 0.6937993857766865, DCG 1.770769324018782, Average Rank 4.547692307692308, ERR 0.0665584599274461
# Average Validation Group Exposure disparity: 0.802170127724484, Group Asymmetric disparity: 0.0011675926787056278
#
# Averages of last 1000 rewards: 0.677502547444191, ndcgs: 0.677502547444191, dcgs: 1.6526766291701345
# Evaluating on validation set: iteration 250/500 of epoch 9
# Epoch 9, Average Validation: NDCG: 0.6900563887421659, DCG 1.7652015171865505, Average Rank 4.544358974358975, ERR 0.06603381154942298
# Average Validation Group Exposure disparity: 0.7936494799442201, Group Asymmetric disparity: 0.003391196129369388
# Epoch 9, Average Validation: NDCG: 0.6994601083043135, DCG 1.7869935140748963, Average Rank 4.524102564102564, ERR 0.06786638987874723
# Average Validation Group Exposure disparity: 0.7211435706994008, Group Asymmetric disparity: 0.00048711778825140996
# {'ndcg': 0.6901386398995516, 'dcg': 1.7639204100079624, 'avg_rank': 4.576410256410257, 'err': 0.06601317004421693, 'avg_group_disparity': 0.7446888101917044, 'avg_group_asym_disparity': 0.0001512658754670737}
# Learnt model for lambda=50.0 has model weights as [-0.04476005956530571, 0.02824261039495468, -0.036569543182849884, 0.012574171647429466, -0.012519139796495438, 0.09882497042417526, -0.03642133250832558, -0.027148455381393433, 0.023725703358650208, 0.03890221193432808, -0.07896747440099716, 0.06373076885938644, 0.029241910204291344, 0.09723679721355438, 0.03361741825938225, -0.24528725445270538, -0.03488107770681381, -0.034133683890104294, 0.009365989826619625, -0.020734470337629318, 0.06932467967271805, 0.10689336806535721, 0.019774915650486946, -0.09705336391925812, -0.1424708068370819, 0.020951615646481514, -0.010919763706624508, -0.0016146519919857383, 0.04312688484787941]
# Starting training with the following config
# Learning rate 0.001, Weight decay 0.0, Sample size 25
# Lambda_reward: 1.0, lambda_ind_fairness:0.0, lambda_group_fairness:100.0
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.6961676236380915, DCG 1.773515244248751, Average Rank 4.50076923076923, ERR 0.06667785183932116
# Average Validation Group Exposure disparity: 0.7474747153299584, Group Asymmetric disparity: 0.0026706122922433963
#
# Averages of last 1000 rewards: 0.6840960786247787, ndcgs: 0.6840960786247787, dcgs: 1.6697768855458133
# Evaluating on validation set: iteration 250/500 of epoch 0
# Epoch 0, Average Validation: NDCG: 0.6913390419013672, DCG 1.7729739825461406, Average Rank 4.5346153846153845, ERR 0.06665376032907441
# Average Validation Group Exposure disparity: 0.7553481252430352, Group Asymmetric disparity: 6.52270583363601e-05
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.6927652952003046, DCG 1.7676876137300461, Average Rank 4.587179487179487, ERR 0.06637973144444423
# Average Validation Group Exposure disparity: 0.769383071822782, Group Asymmetric disparity: 0.0018473871664828156
#
# Averages of last 1000 rewards: 0.685664153880186, ndcgs: 0.685664153880186, dcgs: 1.6935932795130346
# Evaluating on validation set: iteration 250/500 of epoch 1
# Epoch 1, Average Validation: NDCG: 0.6965338476074762, DCG 1.780145416174673, Average Rank 4.495641025641025, ERR 0.06718286661671978
# Average Validation Group Exposure disparity: 0.732271519504269, Group Asymmetric disparity: 0.0008803897257755377
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.69562263752632, DCG 1.7776809303478782, Average Rank 4.50076923076923, ERR 0.06701051766200244
# Average Validation Group Exposure disparity: 0.7674346575090577, Group Asymmetric disparity: 0.0003340357768164126
# Averages of last 1000 rewards: 0.6952411356867126, ndcgs: 0.6952411356867126, dcgs: 1.7300916758970968
# Evaluating on validation set: iteration 250/500 of epoch 2
# Epoch 2, Average Validation: NDCG: 0.7006870004320841, DCG 1.7896377753904684, Average Rank 4.486923076923077, ERR 0.06799335878665294
# Average Validation Group Exposure disparity: 0.7581432160071303, Group Asymmetric disparity: 0.0005013385335885512
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.6923691792847212, DCG 1.766145240015211, Average Rank 4.547435897435897, ERR 0.06617614982346977
# Average Validation Group Exposure disparity: 0.7508127246899078, Group Asymmetric disparity: 0.00015323041514374137
#
# Averages of last 1000 rewards: 0.6764513021649983, ndcgs: 0.6764513021649983, dcgs: 1.627945416512482
# Evaluating on validation set: iteration 250/500 of epoch 3
# Epoch 3, Average Validation: NDCG: 0.7072576027949197, DCG 1.8004745016399955, Average Rank 4.432564102564102, ERR 0.06877149146887111
# Average Validation Group Exposure disparity: 0.7720487394673914, Group Asymmetric disparity: 0.0
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.6977793870073209, DCG 1.7833810374409642, Average Rank 4.4917948717948715, ERR 0.06743129582758402
# Average Validation Group Exposure disparity: 0.7501885964969596, Group Asymmetric disparity: 0.0026228772598805073
#
# Averages of last 1000 rewards: 0.6992964024766578, ndcgs: 0.6992964024766578, dcgs: 1.7532687286607302
# Evaluating on validation set: iteration 250/500 of epoch 4
# Epoch 4, Average Validation: NDCG: 0.6950797431090109, DCG 1.7790202635950079, Average Rank 4.514102564102564, ERR 0.06712020281787688
# Average Validation Group Exposure disparity: 0.7480358523719741, Group Asymmetric disparity: 0.0005267704776515824
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 5
# Epoch 5, Average Validation: NDCG: 0.693420393920316, DCG 1.7782964082348967, Average Rank 4.525897435897436, ERR 0.067095599115667
# Average Validation Group Exposure disparity: 0.7285608426486189, Group Asymmetric disparity: 0.003125953844382322
#
# Averages of last 1000 rewards: 0.6883704280567429, ndcgs: 0.6883704280567429, dcgs: 1.6967973609958786
# Evaluating on validation set: iteration 250/500 of epoch 5
# Epoch 5, Average Validation: NDCG: 0.7007460313394789, DCG 1.7864101011061666, Average Rank 4.5058974358974355, ERR 0.06775653041604174
# Average Validation Group Exposure disparity: 0.7924830229758818, Group Asymmetric disparity: 0.0023460195602272326
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 6
# Epoch 6, Average Validation: NDCG: 0.692878410875847, DCG 1.773376066967654, Average Rank 4.545384615384616, ERR 0.06672505229103548
# Average Validation Group Exposure disparity: 0.765293089019244, Group Asymmetric disparity: 0.0037288269904450413
#
# Averages of last 1000 rewards: 0.6821127436575501, ndcgs: 0.6821127436575501, dcgs: 1.6938555859499898
# Evaluating on validation set: iteration 250/500 of epoch 6
# Epoch 6, Average Validation: NDCG: 0.6880067818725665, DCG 1.7590404881158719, Average Rank 4.563846153846153, ERR 0.06555493966220687
# Average Validation Group Exposure disparity: 0.7707207534881924, Group Asymmetric disparity: 0.0007852085352755967
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 7
# Epoch 7, Average Validation: NDCG: 0.6943839317400324, DCG 1.7745579725542628, Average Rank 4.504615384615384, ERR 0.06672029044337853
# Average Validation Group Exposure disparity: 0.725967212961846, Group Asymmetric disparity: 0.0012051126301411475
#
# Averages of last 1000 rewards: 0.6884549373154157, ndcgs: 0.6884549373154157, dcgs: 1.6818219804879975
# Evaluating on validation set: iteration 250/500 of epoch 7
# Epoch 7, Average Validation: NDCG: 0.7030667881471453, DCG 1.7969599804311402, Average Rank 4.451025641025641, ERR 0.06851232958426626
# Average Validation Group Exposure disparity: 0.6866905378060281, Group Asymmetric disparity: 0.00018333352845273043
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 8
# Epoch 8, Average Validation: NDCG: 0.6945015483329233, DCG 1.7784314598967188, Average Rank 4.561538461538461, ERR 0.06720601298230042
# Average Validation Group Exposure disparity: 0.7324155454737764, Group Asymmetric disparity: 2.0578380477420664e-09
#
# Averages of last 1000 rewards: 0.689627604961957, ndcgs: 0.689627604961957, dcgs: 1.684802015864529
# Evaluating on validation set: iteration 250/500 of epoch 8
# Epoch 8, Average Validation: NDCG: 0.7018411072572062, DCG 1.7943663386299178, Average Rank 4.4569230769230765, ERR 0.06831578588011446
# Average Validation Group Exposure disparity: 0.7016497370755661, Group Asymmetric disparity: 0.0
# Training....
# Evaluating on validation set: iteration 0/500 of epoch 9
# Epoch 9, Average Validation: NDCG: 0.6973292335653254, DCG 1.7818654405411498, Average Rank 4.48, ERR 0.0673017590571377
# Average Validation Group Exposure disparity: 0.7725286760295091, Group Asymmetric disparity: 0.002929278922029146
#
# Averages of last 1000 rewards: 0.6740351581718769, ndcgs: 0.6740351581718769, dcgs: 1.6138743954843413
# Evaluating on validation set: iteration 250/500 of epoch 9
# Epoch 9, Average Validation: NDCG: 0.6998152839776661, DCG 1.7892854066950163, Average Rank 4.4653846153846155, ERR 0.06788388821570136
# Average Validation Group Exposure disparity: 0.7685148482462506, Group Asymmetric disparity: 0.00134217749709016
# Epoch 9, Average Validation: NDCG: 0.7004511835821502, DCG 1.7914947125489502, Average Rank 4.43025641025641, ERR 0.06798020720219226
# Average Validation Group Exposure disparity: 0.7555637998759859, Group Asymmetric disparity: 0.0010177343373495306
# {'ndcg': 0.7010591727985901, 'dcg': 1.7910623426248142, 'avg_rank': 4.447564102564103, 'err': 0.06797883346219628, 'avg_group_disparity': 0.7318578151995283, 'avg_group_asym_disparity': 0.0008909799393415197}
# Learnt model for lambda=100.0 has model weights as [-0.042214736342430115, -0.017796771600842476, -0.03172386810183525, -0.0004052588192280382, 0.0003922059549950063, 0.04391516000032425, -0.009656370617449284, -0.03787996619939804, 0.055475231260061264, 0.05136683210730553, -0.027620315551757812, -0.00827775988727808, 0.0634625032544136, 0.05320415273308754, 0.05197861045598984, -0.16367650032043457, -0.11409766972064972, 0.05201931670308113, -0.001343538868241012, -0.08854854106903076, 0.06209865212440491, 0.05929168313741684, -0.07089849561452866, -0.031044108793139458, -0.03443382307887077, 0.028036193922162056, 0.003510685171931982, 0.015433239750564098, 0.13199904561042786]

# %%
plt_data_pl
# Out:
# array([[8.29642053e-01, 1.84321520e-02],
#        [8.16180549e-01, 1.03863327e-02],
#        [8.16124123e-01, 9.04382583e-03],
#        [8.05925389e-01, 6.39477222e-03],
#        [7.10396780e-01, 2.21628231e-03],
#        [7.06074109e-01, 1.31592079e-04],
#        [7.05714584e-01, 1.39066101e-04],
#        [7.14349438e-01, 4.81621153e-04],
#        [6.94837993e-01, 8.52245267e-04],
#        [6.90138640e-01, 1.51265875e-04],
#        [7.01059173e-01, 8.90979939e-04]])

# %%
from itertools import permutations 
from scipy.optimize import linprog

# %%
def assign_groups(groups):
    G = [[], []]
    for i in range(len(groups)):
        G[groups[i]].append(i)
    return G


def fair_rank(relevances, groups ,lmda = 1):
    n = len(relevances)
    pos_bias = vvector(n)
    G = assign_groups(groups)
    n_g, n_i = 0, 0
    n_g += (len(G)-1)*len(G)
    n_c = n**2 + n_g 
    
    
    c = np.ones(n_c)
    c[:n**2] *= -1
    c[n**2:] *= lmda
    A_eq = []
    #For each Row
    for i in range(n):
        A_temp = np.zeros(n_c)
        A_temp[i*n:(i+1)*n] = 1
        assert(sum(A_temp)==n)
        A_eq.append(A_temp)
        c[i*n:(i+1)*n] *= relevances[i]

    #For each coloumn
    for i in range(n):
        A_temp = np.zeros(n_c)
        A_temp[i:n**2:n] = 1
        assert(sum(A_temp)==n)
        A_eq.append(A_temp)
        #Optimization 
        c[i:n**2:n] *= pos_bias[i] 
    b_eq = np.ones(n*2) 
    A_eq = np.asarray(A_eq)
    bounds = [(0,1) for _ in range(n**2)] + [(0,None) for _ in range(n_g+n_i)]
    
    
    A_ub = []
    b_ub = np.zeros(n_g)
    sum_rels = []
    for group in G:
        #Avoid devision by zero
        sum_rel = np.max([np.sum(np.asarray(relevances)[group]), 0.01])
        sum_rels.append(sum_rel)
    comparisons = list(permutations(np.arange(len(G)),2))
    j = 0
    for a,b in comparisons:
        f = np.zeros(n_c)
        if len(G[a]) > 0 and len(G[b])>0 and sum_rels[a]/len(G[a]) >= sum_rels[b]/len(G[b]):
            for i in range(n):
                tmp1 = len(G[a]) / sum_rels[a] if i in G[a] else 0 
                tmp2 = len(G[b]) / sum_rels[b] if i in G[b] else 0 
                #f[i*n:(i+1)*n] *= max(0, sign*(tmp1 - tmp2))
                f[i*n:(i+1)*n] =  (tmp1 - tmp2)
            for i in range(n):
                f[i:n**2:n] *= pos_bias[i]
            f[n**2+j] = -1
        j += 1
        A_ub.append(f)

    res = linprog(c, A_eq=A_eq, b_eq=b_eq, A_ub=A_ub, b_ub=b_ub, bounds=bounds, 
                                  method = "interior-point")#, options=dict(tol=1e-12),)
    if res.success is False:
        print("Constraint not satisfied!!")
    probabilistic_ranking = np.reshape(res.x[:n**2],(n,n))
    return probabilistic_ranking, res, res.fun

# %%
from baselines import *

# %%
# Linear regression
from sklearn import linear_model
model = linear_model.LinearRegression(fit_intercept=False, normalize=False)
feats, rel = dr.data
feats = np.array([item for sublist in feats for item in sublist])
rel = np.array([item for sublist in rel for item in sublist])
model.fit(feats, rel)
# predictions on validation
feats, rel = vdr.data
se_sum = 0
length = 0
predicted_rels = []
for i, query in enumerate(feats):
    rel_pred = model.predict(query)
    predicted_rels.append(rel_pred)
    se_sum += np.sum((rel_pred - rel[i])**2)
    length += len(rel[i])
print(se_sum/ length)
# Out:
# 0.19917080789519112

# %%
# # for each lambda
# now for each query, estimate all relevances
# we find a fair ranking, find it's loss w.r.t true relevances
lmbdas = np.linspace(0, 0.2, 20)

plt_data = np.zeros((len(lmbdas), 2))

for j, lmbda in enumerate(lmbdas):
    test_losses = []
    test_ndcgs = []
    
    for i in range(len(predicted_rels)):
        true_rels = rel[i]
        pred_rels = predicted_rels[i]
        groups = np.array(feats[i][:, args.group_feat_id], dtype=np.int)
        n = len(groups)
        
        P, _, _ = fair_rank(pred_rels, groups, lmbda)
        
        test_loss = get_fairness_loss(P, true_rels, vvector(n), groups)
        test_losses.append(test_loss)
        
        test_ndcg = get_ndcg(P, true_rels, vvector(n))
        test_ndcgs.append(test_ndcg)
        
    plt_data[j] = [np.mean(test_ndcgs), np.mean(test_losses)]
        
        
    print("Lambda: {}, Average Test Fairness Loss: {}, Average Test NDCG: {}".format(lmbda, 
                                                     np.mean(test_losses), np.mean(test_ndcgs)))

plt.scatter(plt_data[:, 0], plt_data[:, 1])
# Out:
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/scipy/optimize/_linprog_util.py:704: OptimizeWarning: A_eq does not appear to be of full row rank. To improve performance, check the problem formulation for redundant equality constraints.
#   warn(redundancy_warning, OptimizeWarning)
# Lambda: 0.0, Average Test Fairness Loss: 0.014467162787184136, Average Test NDCG: 0.8270660079889922
# Lambda: 0.010526315789473684, Average Test Fairness Loss: 0.011632890573141808, Average Test NDCG: 0.8297516525742858
# Lambda: 0.021052631578947368, Average Test Fairness Loss: 0.009305555175643285, Average Test NDCG: 0.8288665804838848
# Lambda: 0.031578947368421054, Average Test Fairness Loss: 0.009636324742209412, Average Test NDCG: 0.8264644860824426
# Lambda: 0.042105263157894736, Average Test Fairness Loss: 0.009465925979891213, Average Test NDCG: 0.824695332514162
# Lambda: 0.05263157894736842, Average Test Fairness Loss: 0.01432072826416357, Average Test NDCG: 0.8212930853453417
# Lambda: 0.06315789473684211, Average Test Fairness Loss: 0.023736614649109207, Average Test NDCG: 0.8184897697406501
# Lambda: 0.07368421052631578, Average Test Fairness Loss: 0.03621591328296291, Average Test NDCG: 0.8138892020745492
# Lambda: 0.08421052631578947, Average Test Fairness Loss: 0.03730699466519902, Average Test NDCG: 0.8046691459399743
# Lambda: 0.09473684210526316, Average Test Fairness Loss: 0.03561904894050187, Average Test NDCG: 0.8007792025925758
# Lambda: 0.10526315789473684, Average Test Fairness Loss: 0.039252841557340955, Average Test NDCG: 0.7980604037919578
# Lambda: 0.11578947368421053, Average Test Fairness Loss: 0.04138114979554406, Average Test NDCG: 0.797170028390082
# Lambda: 0.12631578947368421, Average Test Fairness Loss: 0.04232404212832062, Average Test NDCG: 0.796682346782879
# Lambda: 0.1368421052631579, Average Test Fairness Loss: 0.04326693544899516, Average Test NDCG: 0.7967426536509146
# Lambda: 0.14736842105263157, Average Test Fairness Loss: 0.046179816727761905, Average Test NDCG: 0.7967426542176468
# Lambda: 0.15789473684210525, Average Test Fairness Loss: 0.046179816489743127, Average Test NDCG: 0.7967426585629734
# Lambda: 0.16842105263157894, Average Test Fairness Loss: 0.046179816717928854, Average Test NDCG: 0.7967426623133753
# Lambda: 0.17894736842105263, Average Test Fairness Loss: 0.046179816709767084, Average Test NDCG: 0.7967426650594096
# Lambda: 0.18947368421052632, Average Test Fairness Loss: 0.04617981670266268, Average Test NDCG: 0.7965805849633091
# Lambda: 0.2, Average Test Fairness Loss: 0.04617981670157146, Average Test NDCG: 0.7965805822078974

# %%
plt.scatter(plt_data[:, 0], plt_data[:, 1])
plt.scatter(plt_data_pl[:, 0], plt_data_pl[:, 1])

# %%
from zehlike import *

args.lr = [0.001]
args.lambda_reward = 1.0
plt_data_4 = []
lambdas = [0.0, 1.0, 10, 100, 1000, 10000, 100000, 1000000]
args.weight_decay = [0.0]
args.epochs = [10]
disparities_mat = np.zeros((len(lambdas), 1))
ndcg_mat = np.zeros((len(lambdas), 1))
for i, lg in enumerate(lambdas):
    args.lambda_group_fairness = lg
    model = LinearModel(D=args.input_dim)
    model = demographic_parity_train(model, dr, vdr, vvector(200), args)
    results = evaluate_model(
            model,
            vdr,
            fairness_evaluation=False,
            group_fairness_evaluation=True,
            deterministic=True,
            args=args,
            num_sample_per_query=100)
    plt_data_4.append([results["ndcg"], results["avg_group_asym_disparity"]])
    ndcg_mat[i, 0], disparities_mat[i,0] = results["ndcg"], results["avg_group_asym_disparity"]
# Out:
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ashudeep/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# {'ndcg': 0.8302883097253424, 'dcg': 2.100585661132893, 'avg_rank': 3.1769230769230767, 'err': 0.09066910566022575, 'avg_group_disparity': 0.8104161834794107, 'avg_group_asym_disparity': 0.020970018299056245}
# {'ndcg': 0.8334984363677026, 'dcg': 2.10423222054325, 'avg_rank': 3.164102564102564, 'err': 0.09097099960973443, 'avg_group_disparity': 0.8293003730381489, 'avg_group_asym_disparity': 0.015523092301494415}
# {'ndcg': 0.8327620522464113, 'dcg': 2.1009847164869124, 'avg_rank': 3.1666666666666665, 'err': 0.09066564783091391, 'avg_group_disparity': 0.82831723937527, 'avg_group_asym_disparity': 0.01688122643151461}
# {'ndcg': 0.83313173660691, 'dcg': 2.1027676282201924, 'avg_rank': 3.1615384615384614, 'err': 0.09080478344441924, 'avg_group_disparity': 0.8123483838129151, 'avg_group_asym_disparity': 0.013098264537883951}
# {'ndcg': 0.8315563120552557, 'dcg': 2.098095480837523, 'avg_rank': 3.1846153846153844, 'err': 0.09048225398016871, 'avg_group_disparity': 0.7837751991690441, 'avg_group_asym_disparity': 0.01895118771569338}
# {'ndcg': 0.8292738379260257, 'dcg': 2.093598870970752, 'avg_rank': 3.1794871794871793, 'err': 0.09010219707247978, 'avg_group_disparity': 0.8083337970164688, 'avg_group_asym_disparity': 0.013284453656110872}
# {'ndcg': 0.8293295537154762, 'dcg': 2.091076083804455, 'avg_rank': 3.2, 'err': 0.08992993320534669, 'avg_group_disparity': 0.8146288999529202, 'avg_group_asym_disparity': 0.013564274210296207}
# {'ndcg': 0.8229259249613297, 'dcg': 2.0757210454023967, 'avg_rank': 3.253846153846154, 'err': 0.0888142303605453, 'avg_group_disparity': 0.8435335899926598, 'avg_group_asym_disparity': 0.01465958539752437}
# {'ndcg': 0.8298695387682251, 'dcg': 2.093195464922717, 'avg_rank': 3.18974358974359, 'err': 0.09003675126587041, 'avg_group_disparity': 0.8030684767965595, 'avg_group_asym_disparity': 0.014142116155437381}
# {'ndcg': 0.8247354713225402, 'dcg': 2.0808083464508704, 'avg_rank': 3.2487179487179487, 'err': 0.08921061212881023, 'avg_group_disparity': 0.8233708018392586, 'avg_group_asym_disparity': 0.016002428757891766}
# {'ndcg': 0.8394786473071779, 'dcg': 2.1196087296853436, 'avg_rank': 3.1487179487179486, 'err': 0.09222595617304823, 'avg_group_disparity': 0.8356501503113062, 'avg_group_asym_disparity': 0.017079722407478293}
# {'ndcg': 0.8345430898009386, 'dcg': 2.1065829132764624, 'avg_rank': 3.135897435897436, 'err': 0.09108028474584265, 'avg_group_disparity': 0.8288625195656039, 'avg_group_asym_disparity': 0.015408558047899297}
# {'ndcg': 0.8257758535564483, 'dcg': 2.0845078293164425, 'avg_rank': 3.2102564102564104, 'err': 0.0893977681290846, 'avg_group_disparity': 0.885463926765797, 'avg_group_asym_disparity': 0.01985406941750952}
# {'ndcg': 0.8264071823817126, 'dcg': 2.0842289283361555, 'avg_rank': 3.2512820512820513, 'err': 0.08953905521822161, 'avg_group_disparity': 0.8508996676297224, 'avg_group_asym_disparity': 0.016449984611996215}
# {'ndcg': 0.8280258504582256, 'dcg': 2.088241737964461, 'avg_rank': 3.2256410256410257, 'err': 0.08980146926491786, 'avg_group_disparity': 0.8393571641225072, 'avg_group_asym_disparity': 0.016162222090811185}
# {'ndcg': 0.8224848836590732, 'dcg': 2.076223297787608, 'avg_rank': 3.2487179487179487, 'err': 0.088856194244354, 'avg_group_disparity': 0.8744088278658145, 'avg_group_asym_disparity': 0.017857752769715667}
# {'ndcg': 0.8277963744495043, 'dcg': 2.0876658272966755, 'avg_rank': 3.212820512820513, 'err': 0.08966265673945392, 'avg_group_disparity': 0.816033982916003, 'avg_group_asym_disparity': 0.013790769157321222}
# {'ndcg': 0.8291582754176378, 'dcg': 2.090803218097585, 'avg_rank': 3.241025641025641, 'err': 0.09001064446272461, 'avg_group_disparity': 0.789114686354913, 'avg_group_asym_disparity': 0.014462423282243515}
# {'ndcg': 0.8238702163394237, 'dcg': 2.078893593209082, 'avg_rank': 3.258974358974359, 'err': 0.08909895448254732, 'avg_group_disparity': 0.8255964818342301, 'avg_group_asym_disparity': 0.014678946499069727}
# {'ndcg': 0.8205725199274528, 'dcg': 2.0698475194134627, 'avg_rank': 3.2897435897435896, 'err': 0.08841277397043693, 'avg_group_disparity': 0.8860506585391248, 'avg_group_asym_disparity': 0.017968172615691936}
# {'ndcg': 0.8351294268896603, 'dcg': 2.10828888771271, 'avg_rank': 3.1923076923076925, 'err': 0.09137435074636178, 'avg_group_disparity': 0.82590844327507, 'avg_group_asym_disparity': 0.01530793251161457}
# {'ndcg': 0.8355147814612367, 'dcg': 2.106570756900354, 'avg_rank': 3.1717948717948716, 'err': 0.09115904097672596, 'avg_group_disparity': 0.8059784050730608, 'avg_group_asym_disparity': 0.01529183864243806}
# {'ndcg': 0.839351856966199, 'dcg': 2.1175026135430413, 'avg_rank': 3.1102564102564103, 'err': 0.09191584665852685, 'avg_group_disparity': 0.7983198948018786, 'avg_group_asym_disparity': 0.01217590699066431}
# {'ndcg': 0.8272126497169329, 'dcg': 2.0883782844532437, 'avg_rank': 3.2153846153846155, 'err': 0.08972826714025411, 'avg_group_disparity': 0.8314180069960105, 'avg_group_asym_disparity': 0.012563940570800493}
# {'ndcg': 0.8286280241832568, 'dcg': 2.0922589477672404, 'avg_rank': 3.2153846153846155, 'err': 0.09009039924676264, 'avg_group_disparity': 0.8307086929523855, 'avg_group_asym_disparity': 0.012435458517810659}
# {'ndcg': 0.8208747009853036, 'dcg': 2.071203284782515, 'avg_rank': 3.2794871794871794, 'err': 0.08850111433234996, 'avg_group_disparity': 0.8568006390112158, 'avg_group_asym_disparity': 0.01582352034418766}
# {'ndcg': 0.8245013143391577, 'dcg': 2.080128735323888, 'avg_rank': 3.246153846153846, 'err': 0.08919581157617669, 'avg_group_disparity': 0.8555974621496019, 'avg_group_asym_disparity': 0.015723810599636887}
# {'ndcg': 0.8192520660693665, 'dcg': 2.068827251162966, 'avg_rank': 3.305128205128205, 'err': 0.08837914483684914, 'avg_group_disparity': 0.867743251137009, 'avg_group_asym_disparity': 0.016081179730588972}
# {'ndcg': 0.8254620959196246, 'dcg': 2.081785698965404, 'avg_rank': 3.258974358974359, 'err': 0.08932932110921302, 'avg_group_disparity': 0.8489542408988291, 'avg_group_asym_disparity': 0.014918063347382764}
# {'ndcg': 0.8269749001548402, 'dcg': 2.086629856305426, 'avg_rank': 3.2615384615384615, 'err': 0.08975485274210085, 'avg_group_disparity': 0.8498218415767088, 'avg_group_asym_disparity': 0.014538779168470796}
# {'ndcg': 0.8334323712671922, 'dcg': 2.1034560827909217, 'avg_rank': 3.151282051282051, 'err': 0.09083890646471021, 'avg_group_disparity': 0.8218312083100056, 'avg_group_asym_disparity': 0.017339793853881725}
# {'ndcg': 0.8292021948096268, 'dcg': 2.0931080822609562, 'avg_rank': 3.182051282051282, 'err': 0.09003049007826483, 'avg_group_disparity': 0.8677208364171003, 'avg_group_asym_disparity': 0.017634487071972287}
# {'ndcg': 0.8222359760377512, 'dcg': 2.0771796441542913, 'avg_rank': 3.258974358974359, 'err': 0.08893789081122459, 'avg_group_disparity': 0.8968265808405067, 'avg_group_asym_disparity': 0.020237346621895275}
# {'ndcg': 0.8230982371613659, 'dcg': 2.0772445964392454, 'avg_rank': 3.223076923076923, 'err': 0.08881164744701459, 'avg_group_disparity': 0.8683858251619696, 'avg_group_asym_disparity': 0.018988019250606735}
# {'ndcg': 0.8194903511273912, 'dcg': 2.0679442051695935, 'avg_rank': 3.2435897435897436, 'err': 0.08812386553638082, 'avg_group_disparity': 0.9033128395301138, 'avg_group_asym_disparity': 0.0222104344582454}
# {'ndcg': 0.8181923986828895, 'dcg': 2.06573249422454, 'avg_rank': 3.292307692307692, 'err': 0.08806631237970265, 'avg_group_disparity': 0.892788173435247, 'avg_group_asym_disparity': 0.02034838626094851}
# {'ndcg': 0.8198027522688865, 'dcg': 2.0697097327983123, 'avg_rank': 3.2974358974358973, 'err': 0.08840410957598525, 'avg_group_disparity': 0.9170534831151967, 'avg_group_asym_disparity': 0.020585581969065722}
# {'ndcg': 0.8210407433924425, 'dcg': 2.071996179642065, 'avg_rank': 3.2717948717948717, 'err': 0.08851879073121763, 'avg_group_disparity': 0.9023062545033795, 'avg_group_asym_disparity': 0.019238455331498563}
# {'ndcg': 0.8155974991873446, 'dcg': 2.0578543595685823, 'avg_rank': 3.3205128205128207, 'err': 0.08746251510514964, 'avg_group_disparity': 0.9133918482558095, 'avg_group_asym_disparity': 0.020033170935121202}
# {'ndcg': 0.8179331993991324, 'dcg': 2.0637271622047972, 'avg_rank': 3.276923076923077, 'err': 0.08783756595363262, 'avg_group_disparity': 0.900448656659159, 'avg_group_asym_disparity': 0.018243914186386444}
# {'ndcg': 0.8265658320163736, 'dcg': 2.0872712935195445, 'avg_rank': 3.230769230769231, 'err': 0.08968989123379634, 'avg_group_disparity': 0.9110579148830833, 'avg_group_asym_disparity': 0.02342362668365685}
# {'ndcg': 0.8201719870810174, 'dcg': 2.074506846419984, 'avg_rank': 3.223076923076923, 'err': 0.08857853642791243, 'avg_group_disparity': 0.9654349018477936, 'avg_group_asym_disparity': 0.020580321767167443}
# {'ndcg': 0.822038288222238, 'dcg': 2.0758472255553024, 'avg_rank': 3.2564102564102564, 'err': 0.08877080417652836, 'avg_group_disparity': 0.9858633713916447, 'avg_group_asym_disparity': 0.023847239888549268}
# {'ndcg': 0.8260157230046135, 'dcg': 2.0826056453409687, 'avg_rank': 3.3153846153846156, 'err': 0.08955858717767877, 'avg_group_disparity': 0.9930326225008302, 'avg_group_asym_disparity': 0.024437692196445763}
# {'ndcg': 0.8222555191116113, 'dcg': 2.0726998117236275, 'avg_rank': 3.312820512820513, 'err': 0.08869302515811951, 'avg_group_disparity': 0.9906043451266003, 'avg_group_asym_disparity': 0.022973087532982116}
# {'ndcg': 0.8149453154791096, 'dcg': 2.0564931508155135, 'avg_rank': 3.382051282051282, 'err': 0.08754468500452292, 'avg_group_disparity': 1.013291095957978, 'avg_group_asym_disparity': 0.024962770344845904}
# {'ndcg': 0.8096833658678988, 'dcg': 2.0480861583116576, 'avg_rank': 3.4, 'err': 0.08687565181566223, 'avg_group_disparity': 0.9894443680158607, 'avg_group_asym_disparity': 0.02422440329450818}
# {'ndcg': 0.8145328940852514, 'dcg': 2.058147755044079, 'avg_rank': 3.3923076923076922, 'err': 0.08772662329729203, 'avg_group_disparity': 1.008361447643683, 'avg_group_asym_disparity': 0.026121271445352194}
# {'ndcg': 0.8217751404216451, 'dcg': 2.0710067465453275, 'avg_rank': 3.3615384615384616, 'err': 0.08869046376137772, 'avg_group_disparity': 0.9995059486748129, 'avg_group_asym_disparity': 0.026160138789301093}
# {'ndcg': 0.8209384302506824, 'dcg': 2.0719337989983995, 'avg_rank': 3.3230769230769233, 'err': 0.08870691907035543, 'avg_group_disparity': 0.9675091158528669, 'avg_group_asym_disparity': 0.023630495936987846}
# {'ndcg': 0.8086818550190062, 'dcg': 2.0422805906821733, 'avg_rank': 3.4974358974358974, 'err': 0.08661712878421392, 'avg_group_disparity': 1.0755350665612533, 'avg_group_asym_disparity': 0.03187192680110638}
# {'ndcg': 0.820203814469462, 'dcg': 2.0741166379210974, 'avg_rank': 3.4153846153846152, 'err': 0.0891048264685974, 'avg_group_disparity': 1.0115062497816678, 'avg_group_asym_disparity': 0.028097385821992598}
# {'ndcg': 0.8137050232834255, 'dcg': 2.057780563132521, 'avg_rank': 3.428205128205128, 'err': 0.08777567501771928, 'avg_group_disparity': 1.0325935065967828, 'avg_group_asym_disparity': 0.028476216418761933}
# {'ndcg': 0.8144833021615411, 'dcg': 2.062800545815568, 'avg_rank': 3.423076923076923, 'err': 0.08814758197091788, 'avg_group_disparity': 1.0596035034994176, 'avg_group_asym_disparity': 0.030123913826030427}
# {'ndcg': 0.8118308156766255, 'dcg': 2.0546818637780175, 'avg_rank': 3.4410256410256412, 'err': 0.0875460671837264, 'avg_group_disparity': 1.0325522399480815, 'avg_group_asym_disparity': 0.028266543694096605}
# {'ndcg': 0.8189690907278876, 'dcg': 2.0722896286514243, 'avg_rank': 3.364102564102564, 'err': 0.08879133974284022, 'avg_group_disparity': 1.0410777354158962, 'avg_group_asym_disparity': 0.02892436886539127}
# {'ndcg': 0.8169534337050334, 'dcg': 2.0703824007223806, 'avg_rank': 3.387179487179487, 'err': 0.08869384105270728, 'avg_group_disparity': 1.057121882296952, 'avg_group_asym_disparity': 0.029792857219732283}
# {'ndcg': 0.813656756771159, 'dcg': 2.063247940017616, 'avg_rank': 3.3923076923076922, 'err': 0.08810409969714517, 'avg_group_disparity': 1.0657735502870944, 'avg_group_asym_disparity': 0.02932305557344003}
# {'ndcg': 0.8123499998380135, 'dcg': 2.0574684301020714, 'avg_rank': 3.423076923076923, 'err': 0.08772177094844215, 'avg_group_disparity': 1.0539831584687833, 'avg_group_asym_disparity': 0.029463025149729597}
# {'ndcg': 0.81426721206188, 'dcg': 2.059331565873594, 'avg_rank': 3.387179487179487, 'err': 0.08780065230300117, 'avg_group_disparity': 1.0663012580999929, 'avg_group_asym_disparity': 0.029989900401923394}
# {'ndcg': 0.8153198124012928, 'dcg': 2.0621490024958042, 'avg_rank': 3.5358974358974358, 'err': 0.08837614203066314, 'avg_group_disparity': 1.070336363738738, 'avg_group_asym_disparity': 0.028724257196107102}
# {'ndcg': 0.8170477978689786, 'dcg': 2.060731599653426, 'avg_rank': 3.494871794871795, 'err': 0.0881982687605057, 'avg_group_disparity': 1.0594031547600082, 'avg_group_asym_disparity': 0.02821197081555209}
# {'ndcg': 0.81527226193298, 'dcg': 2.0549163120474354, 'avg_rank': 3.51025641025641, 'err': 0.08773348459581445, 'avg_group_disparity': 1.0476556583222307, 'avg_group_asym_disparity': 0.02790778590434106}
# {'ndcg': 0.8033815563200913, 'dcg': 2.036025504153515, 'avg_rank': 3.687179487179487, 'err': 0.08656598496270763, 'avg_group_disparity': 1.1814309895327797, 'avg_group_asym_disparity': 0.032835531873460305}
# {'ndcg': 0.8065561182985213, 'dcg': 2.0422139326004753, 'avg_rank': 3.623076923076923, 'err': 0.08695813729558584, 'avg_group_disparity': 1.11657792607056, 'avg_group_asym_disparity': 0.03280145804289777}
# {'ndcg': 0.8107944551927211, 'dcg': 2.0526878614716306, 'avg_rank': 3.5794871794871796, 'err': 0.0877417499470702, 'avg_group_disparity': 1.1117423822630503, 'avg_group_asym_disparity': 0.03280145804289777}
# {'ndcg': 0.8137393144312035, 'dcg': 2.061004445893524, 'avg_rank': 3.482051282051282, 'err': 0.08817156225919635, 'avg_group_disparity': 1.0811417397746395, 'avg_group_asym_disparity': 0.03102459896374884}
# {'ndcg': 0.8106558311586971, 'dcg': 2.0489274568053997, 'avg_rank': 3.5128205128205128, 'err': 0.08726363745027975, 'avg_group_disparity': 1.095889371394631, 'avg_group_asym_disparity': 0.03197321355073591}
# {'ndcg': 0.806501477383446, 'dcg': 2.041273819147948, 'avg_rank': 3.566666666666667, 'err': 0.08674402527420205, 'avg_group_disparity': 1.1566551156547207, 'avg_group_asym_disparity': 0.0325324075060783}
# {'ndcg': 0.8157467222283734, 'dcg': 2.06205530726931, 'avg_rank': 3.443589743589744, 'err': 0.08818790684128182, 'avg_group_disparity': 1.0739867208534786, 'avg_group_asym_disparity': 0.030709956915572368}
# {'ndcg': 0.7658193605029389, 'dcg': 1.9532854633190708, 'avg_rank': 3.9974358974358974, 'err': 0.08053522622631863, 'avg_group_disparity': 1.195530326588386, 'avg_group_asym_disparity': 0.03092273390677163}
# {'ndcg': 0.7916621885969919, 'dcg': 2.011889913718805, 'avg_rank': 3.8743589743589744, 'err': 0.08504815310168094, 'avg_group_disparity': 1.2074227731837808, 'avg_group_asym_disparity': 0.03451809192869821}
# {'ndcg': 0.8183693518384062, 'dcg': 2.0652003818779816, 'avg_rank': 3.582051282051282, 'err': 0.08876455441589601, 'avg_group_disparity': 1.1324032912560642, 'avg_group_asym_disparity': 0.03149684244022105}
# {'ndcg': 0.801586872525688, 'dcg': 2.030056380448607, 'avg_rank': 3.7282051282051283, 'err': 0.08620950344328339, 'avg_group_disparity': 1.1880927574823015, 'avg_group_asym_disparity': 0.03207082948781702}
# {'ndcg': 0.7706736060068277, 'dcg': 1.9550608985802738, 'avg_rank': 4.084615384615384, 'err': 0.0808588127902975, 'avg_group_disparity': 1.2865175889665779, 'avg_group_asym_disparity': 0.03508471803869756}
# {'ndcg': 0.7836862194620094, 'dcg': 1.9848843506359386, 'avg_rank': 3.9256410256410255, 'err': 0.0829159035609281, 'avg_group_disparity': 1.2680500071649847, 'avg_group_asym_disparity': 0.03491149946523659}
# {'ndcg': 0.7924970973566736, 'dcg': 2.008211980364994, 'avg_rank': 3.81025641025641, 'err': 0.0846005593670665, 'avg_group_disparity': 1.237066744432225, 'avg_group_asym_disparity': 0.033185658486106044}
# {'ndcg': 0.8032014050458259, 'dcg': 2.0342774330847373, 'avg_rank': 3.6666666666666665, 'err': 0.08641209280116127, 'avg_group_disparity': 1.1852053047768636, 'avg_group_asym_disparity': 0.03254731666575385}
# {'ndcg': 0.8006665927544302, 'dcg': 2.0327111538503697, 'avg_rank': 3.6769230769230767, 'err': 0.08629938391234637, 'avg_group_disparity': 1.200891424852904, 'avg_group_asym_disparity': 0.03289042447237418}
# {'ndcg': 0.8012696789876501, 'dcg': 2.0334332636231953, 'avg_rank': 3.5487179487179485, 'err': 0.08602558574912005, 'avg_group_disparity': 1.1202722008495982, 'avg_group_asym_disparity': 0.0303642821035435}

# %%
plt_data_4 = np.array(plt_data_4)

# %%
plt_data_4
# Out:
# array([[0.8216944 , 0.01616216],
#        [0.82440639, 0.01689381],
#        [0.82681321, 0.01735145],
#        [0.82291545, 0.01900556],
#        [0.81557957, 0.02753218],
#        [0.81735412, 0.02927786],
#        [0.80865849, 0.03218764],
#        [0.79745179, 0.03219975]])

# %%
plt.scatter(plt_data_4[:, 0], plt_data_4[:, 1])

# %%
def ndcg_vs_disparity_plot(plt_data_mats, names, join=False, ranges=None):
    plt.figure(figsize=(6.5, 4))
    if ranges:
        plt.xlim(ranges[0])
        plt.ylim(ranges[1])
    initialize_params()
    for i, plt_data_mat in enumerate(plt_data_mats):
        if not join:
            plt.scatter(
                plt_data_mats[i][:, 0],
                plt_data_mats[i][:, 1],
                marker="*",
                label=names[i])
        else:
            plt.plot(
                plt_data_mats[i][:, 0],
                plt_data_mats[i][:, 1],
                marker="*",
                linestyle='--',
                label=names[i])
    plt.legend(fontsize=14)
#     plt.title("Utility-Fairness trade-off",y=-0.30)
    plt.xlabel("NDCG")
    plt.ylabel(r'$\hat{\mathcal{D}}_{\rm group}$', fontsize=16)
    plt.grid()
    plt.savefig('./plots/german_tradeoff.pdf', bbox_inches='tight')
    plt.show()

# %%
ndcg_vs_disparity_plot([plt_data, plt_data_pl,  plt_data_4], ["Post-Processing ($\lambda \in [0, 0.2]$)",
                      "Our Method ($\lambda \in [0,100]$ )", 
                      "Zehlike \& Castillo 2018 ($\lambda \in [0, 10^6]$)"], join=True, ranges=[[0.60, 0.85], [0.00, 0.054]])

# %%
ndcg_vs_disparity_plot([plt_data, plt_data_pl], ["Post-Processing ($\lambda \in [0, 0.2]$)",
                      "Our Method ($\lambda \in [0,100]$ )"], join=True, ranges=[[0.60, 0.85], [0.00, 0.054]])
